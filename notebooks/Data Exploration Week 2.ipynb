# %% [markdown]
# ## Start date : July 5th, 2023 (Data Cleaning and Assumptions)
#
# Author : Kenthia
#
# Goals:
#
# Two possible ways to experiment filtering the data:
#
# - Choose which SIC/NAICS code we would use to filter out the data
# - String match the companies to their Parent companies (Big 4) and then utilize the corresponding SIC code for filtering

# %% [markdown]
# ## Experimenting with NAICS Codes:
#
# ### NAICS Codes:
#
# **- 445110 - Supermarkets and Other Grocery (except Convenience) Stores** (Kroger Co and
# Albertsons Companies LLC)
#
# **- 455219 - All Other General Merchandise Retailers**(Costco Wholesale Corporation)
#
# **- 452311 - Warehouse Clubs and Supercenters** (Walmart)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
pd.set_option('display.max_columns', None)
from shapely.geometry import Point
import fiona
import math
import plotly.express as px
from thefuzz import fuzz
from thefuzz import process
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#reading in the dataset 

stores_2022 = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
stores_2022.drop(['Unnamed: 0'],inplace=True,axis=1)
territories = ['PR', 'FM', 'MP', 'GU', 'VI', 'MH']
stores_2022 = stores_2022.drop(stores_2022[stores_2022['STATE'].isin(territories)].index)
stores_2022
# Out:
#                           COMPANY            ADDRESS LINE 1          CITY  \
# 0                          GOMART             55 POSTAL PLZ    MORGANTOWN
# 1                        7-ELEVEN             485 E MAIN ST     EL CENTRO
# 2                   EL SOL MARKET             110 W MAIN ST   WESTMORLAND
# 3            COOL SPRINGS GROCERY           241 WILDWOOD ST    MORGANTOWN
# 4                        CIRCLE K             123 E MAIN ST   WESTMORLAND
# ...                           ...                       ...           ...
# 203498                      H-E-B  1434 W WELLS BRANCH PKWY  PFLUGERVILLE
# 203499  ELECTRIC CHARGING STATION            1A LAKEVIEW DR      HALFMOON
# 203500                  SAC N PAC  2101 N STATE HIGHWAY 123    SAN MARCOS
# 203501              PRICE CHOPPER             1 KENDALL WAY  BALLSTON SPA
# 203502           CUMBERLAND FARMS           77 DELAWARE AVE        COHOES
#
#        STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 0         WV    26508  7005.0         61.0        304       2
# 1         CA    92243  2619.0         25.0        760       2
# 2         CA    92281     NaN         25.0        760       2
# 3         WV    26505  3141.0         61.0        304       2
# 4         CA    92281     NaN         25.0        760       2
# ...      ...      ...     ...          ...        ...     ...
# 203498    TX    78660  3153.0        453.0        512       2
# 203499    NY    12065  4101.0         91.0        518       2
# 203500    TX    78666  1441.0        209.0        512       2
# 203501    NY    12020  4399.0         91.0        518       2
# 203502    NY    12047  3757.0          1.0        518       2
#
#        LOCATION EMPLOYEE SIZE CODE LOCATION SALES VOLUME CODE  \
# 0                                C                          C
# 1                                B                          C
# 2                                B                          C
# 3                                A                          A
# 4                                B                          C
# ...                            ...                        ...
# 203498                           G                          H
# 203499                         NaN                        NaN
# 203500                           A                          A
# 203501                           F                          F
# 203502                           B                          C
#
#         PRIMARY SIC CODE          SIC6_DESCRIPTIONS  PRIMARY NAICS CODE  \
# 0                 541103         CONVENIENCE STORES          44512001.0
# 1                 541103         CONVENIENCE STORES          44512001.0
# 2                 541105             GROCERS-RETAIL          44511003.0
# 3                 541105             GROCERS-RETAIL          44511003.0
# 4                 541103         CONVENIENCE STORES          44512001.0
# ...                  ...                        ...                 ...
# 203498            541105             GROCERS-RETAIL          44511003.0
# 203499            554112  ELECTRIC CHARGING STATION          44719010.0
# 203500            541103         CONVENIENCE STORES          44512001.0
# 203501            541105             GROCERS-RETAIL          44511003.0
# 203502            541103         CONVENIENCE STORES          44512001.0
#
#                                       NAICS8 DESCRIPTIONS  SIC CODE  \
# 0                                      CONVENIENCE STORES  554101.0
# 1                                      CONVENIENCE STORES  554101.0
# 2       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 3       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 4                                      CONVENIENCE STORES  554101.0
# ...                                                   ...       ...
# 203498  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  554101.0
# 203499                            OTHER GASOLINE STATIONS       NaN
# 203500                                 CONVENIENCE STORES  541105.0
# 203501  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  543101.0
# 203502                                 CONVENIENCE STORES       NaN
#
#                      SIC6_DESCRIPTIONS (SIC)  SIC CODE 1  \
# 0            SERVICE STATIONS-GASOLINE & OIL    554110.0
# 1            SERVICE STATIONS-GASOLINE & OIL         NaN
# 2                                        NaN         NaN
# 3                                        NaN         NaN
# 4            SERVICE STATIONS-GASOLINE & OIL         NaN
# ...                                      ...         ...
# 203498       SERVICE STATIONS-GASOLINE & OIL    729954.0
# 203499                                   NaN         NaN
# 203500                        GROCERS-RETAIL         NaN
# 203501  FRUITS & VEGETABLES & PRODUCE-RETAIL    546103.0
# 203502                                   NaN         NaN
#
#                     SIC6_DESCRIPTIONS (SIC1)  SIC CODE 2  \
# 0                          ALTERNATIVE FUELS         NaN
# 1                                        NaN         NaN
# 2                                        NaN         NaN
# 3                                        NaN         NaN
# 4                                        NaN         NaN
# ...                                      ...         ...
# 203498  VEHICLE & DRIVERS LICENSING SERVICES    581208.0
# 203499                                   NaN         NaN
# 203500                                   NaN         NaN
# 203501                     BAKERS-CAKE & PIE         NaN
# 203502                                   NaN         NaN
#
#        SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3 SIC6_DESCRIPTIONS(SIC3)  \
# 0                          NaN         NaN                     NaN
# 1                          NaN         NaN                     NaN
# 2                          NaN         NaN                     NaN
# 3                          NaN         NaN                     NaN
# 4                          NaN         NaN                     NaN
# ...                        ...         ...                     ...
# 203498             RESTAURANTS         NaN                     NaN
# 203499                     NaN         NaN                     NaN
# 203500                     NaN         NaN                     NaN
# 203501                     NaN         NaN                     NaN
# 203502                     NaN         NaN                     NaN
#
#         SIC CODE 4 SIC6_DESCRIPTIONS(SIC4)  ARCHIVE VERSION YEAR  \
# 0              NaN                     NaN                  2022
# 1              NaN                     NaN                  2022
# 2              NaN                     NaN                  2022
# 3              NaN                     NaN                  2022
# 4              NaN                     NaN                  2022
# ...            ...                     ...                   ...
# 203498         NaN                     NaN                  2022
# 203499         NaN                     NaN                  2022
# 203500         NaN                     NaN                  2022
# 203501         NaN                     NaN                  2022
# 203502         NaN                     NaN                  2022
#
#         YELLOW PAGE CODE  EMPLOYEE SIZE (5) - LOCATION  \
# 0                21303.0                          13.0
# 1                    NaN                           6.0
# 2                39106.0                           5.0
# 3                39106.0                           2.0
# 4                    NaN                           6.0
# ...                  ...                           ...
# 203498           39106.0                         270.0
# 203499               NaN                           NaN
# 203500           21303.0                           1.0
# 203501               NaN                         100.0
# 203502               NaN                           8.0
#
#         SALES VOLUME (9) - LOCATION  BUSINESS STATUS CODE  \
# 0                            2482.0                     2
# 1                            1273.0                     2
# 2                            1061.0                     9
# 3                             382.0                     9
# 4                            1273.0                     2
# ...                             ...                   ...
# 203498                      71857.0                     2
# 203499                          0.0                     9
# 203500                        304.0                     2
# 203501                      18804.0                     2
# 203502                       1346.0                     2
#
#        INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  OFFICE SIZE CODE  \
# 0                               NaN               NaN               NaN
# 1                                 W               NaN               NaN
# 2                               NaN               NaN               NaN
# 3                               NaN               NaN               NaN
# 4                                 F               NaN               NaN
# ...                             ...               ...               ...
# 203498                            F               NaN               NaN
# 203499                            J               NaN               NaN
# 203500                          NaN               NaN               NaN
# 203501                            U               NaN               NaN
# 203502                            1               NaN               NaN
#
#         COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  PARENT NUMBER  \
# 0                          NaN  998372387                NaN    124929449.0
# 1                          NaN  495660326                NaN      5863311.0
# 2                          NaN  519605455                NaN            NaN
# 3                          NaN  817953730                NaN            NaN
# 4                          NaN  855113817                NaN    450720289.0
# ...                        ...        ...                ...            ...
# 203498                     NaN  403451198                NaN    436443592.0
# 203499                     NaN  739034319                NaN            NaN
# 203500                     NaN  898604384        625576871.0      5863311.0
# 203501                     NaN  734631888          4352464.0    769874507.0
# 203502                     NaN  736237448          9588435.0    714232249.0
#
#         PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 0                              50.0                    389500.0
# 1                             800.0                   1272634.0
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                             650.0                   4981020.0
# ...                             ...                         ...
# 203498                       1000.0                  23000000.0
# 203499                          NaN                         NaN
# 203500                        800.0                   1272634.0
# 203501                          NaN                         NaN
# 203502                          NaN                   3761100.0
#
#        PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 0                              E                        I  998372387.0
# 1                              H                        K  495660326.0
# 2                            NaN                      NaN          NaN
# 3                            NaN                      NaN          NaN
# 4                              H                        J          NaN
# ...                          ...                      ...          ...
# 203498                         I                        K  403451198.0
# 203499                       NaN                      NaN          NaN
# 203500                         H                        K  729087954.0
# 203501                       NaN                      NaN  734631888.0
# 203502                       NaN                        K  736237448.0
#
#        ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 0                         NaN                7       11000.0           3.0
# 1                         NaN                7       11400.0           3.0
# 2                         NaN                3       10200.0           1.0
# 3                         NaN                7       10400.0           4.0
# 4                         NaN                3       10200.0           1.0
# ...                       ...              ...           ...           ...
# 203498                    NaN                8        1840.0           3.0
# 203499                    NaN                7       62405.0           1.0
# 203500                    NaN                8       10400.0           3.0
# 203501                    NaN                7       61901.0           5.0
# 203502                    NaN                6       12700.0           1.0
#
#          LATITUDE   LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 0       39.594376  -79.954437          P    34060.0         2.0     390.0
# 1       32.792679 -115.536058          0    20940.0         2.0       0.0
# 2       33.051800 -115.581800          X    20940.0         2.0       0.0
# 3       39.652885  -79.986398          P    34060.0         2.0     390.0
# 4       33.051800 -115.581800          X    20940.0         2.0       0.0
# ...           ...         ...        ...        ...         ...       ...
# 203498  30.442331  -97.664580          P    12420.0         2.0       0.0
# 203499  42.851508  -73.767767          0    10580.0         2.0     104.0
# 203500  29.845163  -97.940228          P    12420.0         2.0       0.0
# 203501  42.973191  -73.794719          P    10580.0         2.0     104.0
# 203502  42.777351  -73.682198          P    10580.0         2.0     104.0
#
#         FIPS CODE
# 0         54061.0
# 1          6025.0
# 2          6025.0
# 3         54061.0
# 4          6025.0
# ...           ...
# 203498    48453.0
# 203499    36091.0
# 203500    48209.0
# 203501    36091.0
# 203502    36001.0
#
# [202478 rows x 53 columns]

# %%
#filter by NAICS code "44511" - SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS

#grocery_naics = stores_2022.loc[(stores_2022["PRIMARY NAICS CODE"] == 445110) | (stores_2022["PRIMARY NAICS CODE"] == 455219 ) | (stores_2022["PRIMARY NAICS CODE"] == 452311) ]

grocery_naics = stores_2022.loc[stores_2022[['PRIMARY NAICS CODE']].astype(str).apply(lambda x: x.str.startswith('44511')).any(axis=1)]
grocery_naics
# Out:
#                      COMPANY            ADDRESS LINE 1           CITY STATE  \
# 2              EL SOL MARKET             110 W MAIN ST    WESTMORLAND    CA
# 3       COOL SPRINGS GROCERY           241 WILDWOOD ST     MORGANTOWN    WV
# 5         EL SOL MEAT MARKET       1100 MEADOWS RD # B       CALEXICO    CA
# 7                     KROGER            1600 S OHIO ST   MARTINSVILLE    IN
# 8                FOOD 4 LESS        2420 COTTONWOOD DR      EL CENTRO    CA
# ...                      ...                       ...            ...   ...
# 203493               SAFEWAY  2204 W NOB HILL BLVD # A         YAKIMA    WA
# 203496            CORNUCOPIA        1104 THORPE LN # J     SAN MARCOS    TX
# 203497                T-MART            103 SUNRISE DR  SUNRISE BEACH    TX
# 203498                 H-E-B  1434 W WELLS BRANCH PKWY   PFLUGERVILLE    TX
# 203501         PRICE CHOPPER             1 KENDALL WAY   BALLSTON SPA    NY
#
#         ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 2         92281     NaN         25.0        760       2
# 3         26505  3141.0         61.0        304       2
# 5         92231  5917.0         25.0        760       2
# 7         46151  3317.0        109.0        765       2
# 8         92243  1604.0         25.0        760       2
# ...         ...     ...          ...        ...     ...
# 203493    98902  6200.0         77.0        509       2
# 203496    78666  7126.0        209.0        512       2
# 203497    78643  9287.0        299.0        325       2
# 203498    78660  3153.0        453.0        512       2
# 203501    12020  4399.0         91.0        518       2
#
#        LOCATION EMPLOYEE SIZE CODE LOCATION SALES VOLUME CODE  \
# 2                                B                          C
# 3                                A                          A
# 5                                D                          E
# 7                                F                          G
# 8                                E                          F
# ...                            ...                        ...
# 203493                           F                          G
# 203496                           B                          C
# 203497                           A                          A
# 203498                           G                          H
# 203501                           F                          F
#
#         PRIMARY SIC CODE     SIC6_DESCRIPTIONS  PRIMARY NAICS CODE  \
# 2                 541105        GROCERS-RETAIL          44511003.0
# 3                 541105        GROCERS-RETAIL          44511003.0
# 5                 541105        GROCERS-RETAIL          44511003.0
# 7                 541105        GROCERS-RETAIL          44511003.0
# 8                 541105        GROCERS-RETAIL          44511003.0
# ...                  ...                   ...                 ...
# 203493            541105        GROCERS-RETAIL          44511003.0
# 203496            541108  GROCERS-HEALTH FOODS          44511007.0
# 203497            541105        GROCERS-RETAIL          44511003.0
# 203498            541105        GROCERS-RETAIL          44511003.0
# 203501            541105        GROCERS-RETAIL          44511003.0
#
#                                       NAICS8 DESCRIPTIONS  SIC CODE  \
# 2       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 3       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 5       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  542107.0
# 7       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 8       SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# ...                                                   ...       ...
# 203493  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  546102.0
# 203496  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  549904.0
# 203497  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  343201.0
# 203498  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  554101.0
# 203501  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  543101.0
#
#                      SIC6_DESCRIPTIONS (SIC)  SIC CODE 1  \
# 2                                        NaN         NaN
# 3                                        NaN         NaN
# 5                                MEAT-RETAIL         NaN
# 7                                        NaN         NaN
# 8                                        NaN         NaN
# ...                                      ...         ...
# 203493                         BAKERS-RETAIL    599201.0
# 203496            VITAMIN & FOOD SUPPLEMENTS    549913.0
# 203497     PLUMBING FIXTURES & SUPPLIES-MFRS    572222.0
# 203498       SERVICE STATIONS-GASOLINE & OIL    729954.0
# 203501  FRUITS & VEGETABLES & PRODUCE-RETAIL    546103.0
#
#                     SIC6_DESCRIPTIONS (SIC1)  SIC CODE 2  \
# 2                                        NaN         NaN
# 3                                        NaN         NaN
# 5                                        NaN         NaN
# 7                                        NaN         NaN
# 8                                        NaN         NaN
# ...                                      ...         ...
# 203493                       FLORISTS-RETAIL    592102.0
# 203496                                 HERBS    514949.0
# 203497                          PUMPS-RETAIL    508444.0
# 203498  VEHICLE & DRIVERS LICENSING SERVICES    581208.0
# 203501                     BAKERS-CAKE & PIE         NaN
#
#         SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3   SIC6_DESCRIPTIONS(SIC3)  \
# 2                           NaN         NaN                       NaN
# 3                           NaN         NaN                       NaN
# 5                           NaN         NaN                       NaN
# 7                           NaN         NaN                       NaN
# 8                           NaN         NaN                       NaN
# ...                         ...         ...                       ...
# 203493           LIQUORS-RETAIL         NaN                       NaN
# 203496  NATURAL FOODS-WHOLESALE    549935.0  ORGANIC FOODS & SERVICES
# 203497             PUMPS (WHLS)    525104.0           HARDWARE-RETAIL
# 203498              RESTAURANTS         NaN                       NaN
# 203501                      NaN         NaN                       NaN
#
#         SIC CODE 4                SIC6_DESCRIPTIONS(SIC4)  \
# 2              NaN                                    NaN
# 3              NaN                                    NaN
# 5              NaN                                    NaN
# 7              NaN                                    NaN
# 8              NaN                                    NaN
# ...            ...                                    ...
# 203493         NaN                                    NaN
# 203496    512205.0  VITAMINS & FOOD SUPPLEMENTS-WHOLESALE
# 203497    594131.0                 FISHING TACKLE-DEALERS
# 203498         NaN                                    NaN
# 203501         NaN                                    NaN
#
#         ARCHIVE VERSION YEAR  YELLOW PAGE CODE  EMPLOYEE SIZE (5) - LOCATION  \
# 2                       2022           39106.0                           5.0
# 3                       2022           39106.0                           2.0
# 5                       2022               NaN                          29.0
# 7                       2022           39106.0                         102.0
# 8                       2022           39106.0                          70.0
# ...                      ...               ...                           ...
# 203493                  2022               NaN                         145.0
# 203496                  2022               NaN                           6.0
# 203497                  2022               NaN                           2.0
# 203498                  2022           39106.0                         270.0
# 203501                  2022               NaN                         100.0
#
#         SALES VOLUME (9) - LOCATION  BUSINESS STATUS CODE  \
# 2                            1061.0                     9
# 3                             382.0                     9
# 5                            6153.0                     9
# 7                           21931.0                     2
# 8                           14851.0                     2
# ...                             ...                   ...
# 203493                      35556.0                     2
# 203496                       1823.0                     9
# 203497                        441.0                     9
# 203498                      71857.0                     2
# 203501                      18804.0                     2
#
#        INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  OFFICE SIZE CODE  \
# 2                               NaN               NaN               NaN
# 3                               NaN               NaN               NaN
# 5                               NaN               NaN               NaN
# 7                                 P               NaN               NaN
# 8                               ï¿½               NaN               NaN
# ...                             ...               ...               ...
# 203493                            V               NaN               NaN
# 203496                          NaN            1970.0               NaN
# 203497                          NaN               NaN               NaN
# 203498                            F               NaN               NaN
# 203501                            U               NaN               NaN
#
#         COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  PARENT NUMBER  \
# 2                          NaN  519605455                NaN            NaN
# 3                          NaN  817953730                NaN            NaN
# 5                          NaN  995912391                NaN            NaN
# 7                          NaN  140765967                NaN      7521503.0
# 8                          NaN  215261702        402627138.0      7521503.0
# ...                        ...        ...                ...            ...
# 203493                     NaN  840802979          9606492.0      5995907.0
# 203496                     NaN  164470890                NaN            NaN
# 203497                     NaN  880617683                NaN            NaN
# 203498                     NaN  403451198                NaN    436443592.0
# 203501                     NaN  734631888          4352464.0    769874507.0
#
#         PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 5                               NaN                         NaN
# 7                            1200.0                 137888000.0
# 8                            1200.0                 137888000.0
# ...                             ...                         ...
# 203493                        800.0                         NaN
# 203496                          NaN                         NaN
# 203497                          NaN                         NaN
# 203498                       1000.0                  23000000.0
# 203501                          NaN                         NaN
#
#        PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 2                            NaN                      NaN          NaN
# 3                            NaN                      NaN          NaN
# 5                            NaN                      NaN  995912391.0
# 7                              I                        I  140765967.0
# 8                              I                        I  215261702.0
# ...                          ...                      ...          ...
# 203493                         H                      NaN  840802979.0
# 203496                       NaN                      NaN          NaN
# 203497                       NaN                      NaN          NaN
# 203498                         I                        K  403451198.0
# 203501                       NaN                      NaN  734631888.0
#
#        ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 2                         NaN                3       10200.0           1.0
# 3                         NaN                7       10400.0           4.0
# 5                         NaN                7       12002.0           2.0
# 7                         NaN                7      510701.0           2.0
# 8                         NaN                7       11201.0           1.0
# ...                       ...              ...           ...           ...
# 203493                    NaN                7        1100.0           1.0
# 203496                    NaN                8       10304.0           1.0
# 203497                    NaN                5      970300.0           1.0
# 203498                    NaN                8        1840.0           3.0
# 203501                    NaN                7       61901.0           5.0
#
#          LATITUDE   LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 2       33.051800 -115.581800          X    20940.0         2.0       0.0
# 3       39.652885  -79.986398          P    34060.0         2.0     390.0
# 5       32.679923 -115.482166          P    20940.0         2.0       0.0
# 7       39.411880  -86.425148          P    26900.0         2.0     294.0
# 8       32.815719 -115.572166          P    20940.0         2.0       0.0
# ...           ...         ...        ...        ...         ...       ...
# 203493  46.584035 -120.539230          P    49420.0         2.0       0.0
# 203496  29.886013  -97.924983          P    12420.0         2.0       0.0
# 203497  30.593381  -98.425843          P        0.0         NaN       0.0
# 203498  30.442331  -97.664580          P    12420.0         2.0       0.0
# 203501  42.973191  -73.794719          P    10580.0         2.0     104.0
#
#         FIPS CODE
# 2          6025.0
# 3         54061.0
# 5          6025.0
# 7         18109.0
# 8          6025.0
# ...           ...
# 203493    53077.0
# 203496    48209.0
# 203497    48299.0
# 203498    48453.0
# 203501    36091.0
#
# [75043 rows x 53 columns]

# %%
grocery_type= grocery_naics["PRIMARY NAICS CODE"].unique().tolist()
grocery_type
# Out:
# [44511003.0, 44511006.0, 44511007.0, 44511004.0]

# %% [markdown]
# # Will have to find another way to filter as NAICS CODES is not giving us exactly what we want.

# %% [markdown]
# ## Some String Matching work and Validation
# ### ( Just a Snippet - Other lists in other group members notebook )

# %%
#Ahold Delhaize:

stores_2022.loc[stores_2022["COMPANY"] =="GIANT EAGLE FLORAL"]

#Checking for Actual supermarkets owned by Ahold Delhaize:

 #FRESH DIRECT - remove 
 #GIANT EAGLE - keep 
 #GIANT EAGLE FLORAL - remove
 #PEA POD - keep
 #BFRESH MARKET - keep
# Out:
#                  COMPANY   ADDRESS LINE 1        CITY STATE  ZIPCODE  ZIP4  \
# 1074  GIANT EAGLE FLORAL  5620 BAPTIST RD  PITTSBURGH    PA    15236   NaN
#
#       COUNTY CODE  AREA CODE  IDCODE LOCATION EMPLOYEE SIZE CODE  \
# 1074          3.0        412       2                           A
#
#      LOCATION SALES VOLUME CODE  PRIMARY SIC CODE SIC6_DESCRIPTIONS  \
# 1074                          A            541105    GROCERS-RETAIL
#
#       PRIMARY NAICS CODE                                NAICS8 DESCRIPTIONS  \
# 1074          44511003.0  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS
#
#       SIC CODE SIC6_DESCRIPTIONS (SIC)  SIC CODE 1 SIC6_DESCRIPTIONS (SIC1)  \
# 1074  599201.0         FLORISTS-RETAIL         NaN                      NaN
#
#       SIC CODE 2 SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3 SIC6_DESCRIPTIONS(SIC3)  \
# 1074         NaN                     NaN         NaN                     NaN
#
#       SIC CODE 4 SIC6_DESCRIPTIONS(SIC4)  ARCHIVE VERSION YEAR  \
# 1074         NaN                     NaN                  2022
#
#       YELLOW PAGE CODE  EMPLOYEE SIZE (5) - LOCATION  \
# 1074               NaN                           1.0
#
#       SALES VOLUME (9) - LOCATION  BUSINESS STATUS CODE  \
# 1074                        207.0                     2
#
#      INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  OFFICE SIZE CODE  \
# 1074                          NaN               NaN               NaN
#
#       COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  PARENT NUMBER  \
# 1074                     NaN  404236039                NaN      6829915.0
#
#       PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 1074                       1300.0                    389500.0
#
#      PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 1074                         I                        I          NaN
#
#      ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 1074                    NaN                7      477300.0           5.0
#
#       LATITUDE  LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 1074   40.3446   -79.9775          X    38300.0         2.0     430.0
#
#       FIPS CODE
# 1074    42003.0

# %%
#KROGERS:

stores_2022.loc[stores_2022["COMPANY"] =="BAKER STREET MARKET"]

#Checking for KROGERS owned supermarkets/companies:

#BAKER'S - keep 
#BAKERS- keep 
#BAKER'S MARKET - remove
#BAKER STREET MARKET - remove
#FRY'S FOOD - keep 
#GERBES SUPER MARKET - keep
# Out:
#                   COMPANY ADDRESS LINE 1       CITY STATE  ZIPCODE    ZIP4  \
# 8484  BAKER STREET MARKET    96 BAKER ST  MAPLEWOOD    NJ     7040  2502.0
#
#       COUNTY CODE  AREA CODE  IDCODE LOCATION EMPLOYEE SIZE CODE  \
# 8484         13.0        973       2                           A
#
#      LOCATION SALES VOLUME CODE  PRIMARY SIC CODE SIC6_DESCRIPTIONS  \
# 8484                          A            541105    GROCERS-RETAIL
#
#       PRIMARY NAICS CODE                                NAICS8 DESCRIPTIONS  \
# 8484          44511003.0  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS
#
#       SIC CODE SIC6_DESCRIPTIONS (SIC)  SIC CODE 1 SIC6_DESCRIPTIONS (SIC1)  \
# 8484       NaN                     NaN         NaN                      NaN
#
#       SIC CODE 2 SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3 SIC6_DESCRIPTIONS(SIC3)  \
# 8484         NaN                     NaN         NaN                     NaN
#
#       SIC CODE 4 SIC6_DESCRIPTIONS(SIC4)  ARCHIVE VERSION YEAR  \
# 8484         NaN                     NaN                  2022
#
#       YELLOW PAGE CODE  EMPLOYEE SIZE (5) - LOCATION  \
# 8484               NaN                           2.0
#
#       SALES VOLUME (9) - LOCATION  BUSINESS STATUS CODE  \
# 8484                        486.0                     9
#
#      INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  OFFICE SIZE CODE  \
# 8484                          NaN            2019.0               NaN
#
#       COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  PARENT NUMBER  \
# 8484                     NaN  746507627                NaN            NaN
#
#       PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 8484                          NaN                         NaN
#
#      PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 8484                       NaN                      NaN          NaN
#
#      ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 8484                    NaN                7       19900.0           2.0
#
#        LATITUDE  LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 8484  40.730231 -74.279081          0    35620.0         2.0     408.0
#
#       FIPS CODE
# 8484    34013.0

# %%
#Albertsons:

stores_2022.loc[stores_2022["COMPANY"] =="CARRS QUALITY CTR PALMER SHPG"]

#Checking for Albertsons owned supermarkets/companies:

#SHAW'S SUPERMARKET - keep 
#SHAW'S SUPERMARKETS INC - keep 
#SUPER SAVER COST PLUS - keep 
#SAAR'S SUPER SAVER FOODS - keep
#CARRS QUALITY CTR PALMER SHPG - keep 
#BIG CHEAP CASH & CARR - remove
# Out:
#                              COMPANY            ADDRESS LINE 1    CITY STATE  \
# 14700  CARRS QUALITY CTR PALMER SHPG  664 E PALMER WASILLA HWY  PALMER    AK
#
#        ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 14700    99645  6573.0        170.0        907       2
#
#       LOCATION EMPLOYEE SIZE CODE LOCATION SALES VOLUME CODE  \
# 14700                           B                          C
#
#        PRIMARY SIC CODE SIC6_DESCRIPTIONS  PRIMARY NAICS CODE  \
# 14700            541105    GROCERS-RETAIL          44511003.0
#
#                                      NAICS8 DESCRIPTIONS  SIC CODE  \
# 14700  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
#
#       SIC6_DESCRIPTIONS (SIC)  SIC CODE 1 SIC6_DESCRIPTIONS (SIC1)  \
# 14700                     NaN         NaN                      NaN
#
#        SIC CODE 2 SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3 SIC6_DESCRIPTIONS(SIC3)  \
# 14700         NaN                     NaN         NaN                     NaN
#
#        SIC CODE 4 SIC6_DESCRIPTIONS(SIC4)  ARCHIVE VERSION YEAR  \
# 14700         NaN                     NaN                  2022
#
#        YELLOW PAGE CODE  EMPLOYEE SIZE (5) - LOCATION  \
# 14700               NaN                           6.0
#
#        SALES VOLUME (9) - LOCATION  BUSINESS STATUS CODE  \
# 14700                       1857.0                     9
#
#       INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  OFFICE SIZE CODE  \
# 14700                          NaN               NaN               NaN
#
#        COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  PARENT NUMBER  \
# 14700                     NaN  427093379                NaN            NaN
#
#        PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 14700                          NaN                         NaN
#
#       PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 14700                       NaN                      NaN          NaN
#
#       ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 14700                    NaN                7        1202.0           2.0
#
#         LATITUDE   LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 14700  61.599356 -149.133774          4    11260.0         2.0       0.0
#
#        FIPS CODE
# 14700     2170.0

# %% [markdown]
# ### Research Question 2
#
#
# To what extent is corporate concentration found today within the United States grocery industry? How does this vary by state or geographic region? How has the monopoly power of groceries’ parent companies changed over time?
