# %% [markdown]
# **The goal of this notebook is to work on the string matching so that we can more accurately choose all of the stores. The problem with the current string matching is that it excudes other things that should be matched**

# %%
import pandas as pd
import numpy as np 
import geopandas as gpd
import matplotlib 
from matplotlib import pyplot as plt 
pd.set_option('display.max_columns',None)
import seaborn as sns 
from shapely.geometry import Point, Polygon 


dataset = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
dataset.drop(['Unnamed: 0'],inplace=True,axis=1)
dataset

pure = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
pure.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
pure = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
pure.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
dataset.loc[dataset["PRIMARY NAICS CODE"] == 445110]
# Out:
# Empty DataFrame
# Columns: [COMPANY, ADDRESS LINE 1, CITY, STATE, ZIPCODE, ZIP4, COUNTY CODE, AREA CODE, IDCODE, LOCATION EMPLOYEE SIZE CODE, LOCATION SALES VOLUME CODE, PRIMARY SIC CODE, SIC6_DESCRIPTIONS, PRIMARY NAICS CODE, NAICS8 DESCRIPTIONS, SIC CODE, SIC6_DESCRIPTIONS (SIC), SIC CODE 1, SIC6_DESCRIPTIONS (SIC1), SIC CODE 2, SIC6_DESCRIPTIONS(SIC2), SIC CODE 3, SIC6_DESCRIPTIONS(SIC3), SIC CODE 4, SIC6_DESCRIPTIONS(SIC4), ARCHIVE VERSION YEAR, YELLOW PAGE CODE, EMPLOYEE SIZE (5) - LOCATION, SALES VOLUME (9) - LOCATION, BUSINESS STATUS CODE, INDUSTRY SPECIFIC FIRST BYTE, YEAR ESTABLISHED, OFFICE SIZE CODE, COMPANY HOLDING STATUS, ABI, SUBSIDIARY NUMBER, PARENT NUMBER, PARENT ACTUAL EMPLOYEE SIZE, PARENT ACTUAL SALES VOLUME, PARENT EMPLOYEE SIZE CODE, PARENT SALES VOLUME CODE, SITE NUMBER, ADDRESS TYPE INDICATOR, POPULATION CODE, CENSUS TRACT, CENSUS BLOCK, LATITUDE, LONGITUDE, MATCH CODE, CBSA CODE, CBSA LEVEL, CSA CODE, FIPS CODE]
# Index: []

# %%
stores_2022 = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
stores_2022.drop(['Unnamed: 0'],inplace=True,axis=1)
territories = ['PR', 'FM', 'MP', 'GU', 'VI', 'MH']
stores_2022 = stores_2022.drop(stores_2022[stores_2022['STATE'].isin(territories)].index)
stores_2022.head(10)
# Out:
#                   COMPANY       ADDRESS LINE 1              CITY STATE  \
# 0                  GOMART        55 POSTAL PLZ        MORGANTOWN    WV
# 1                7-ELEVEN        485 E MAIN ST         EL CENTRO    CA
# 2           EL SOL MARKET        110 W MAIN ST       WESTMORLAND    CA
# 3    COOL SPRINGS GROCERY      241 WILDWOOD ST        MORGANTOWN    WV
# 4                CIRCLE K        123 E MAIN ST       WESTMORLAND    CA
# 5      EL SOL MEAT MARKET  1100 MEADOWS RD # B          CALEXICO    CA
# 6                    AMPM   73434 29 PALMS HWY  TWENTYNINE PALMS    CA
# 7                  KROGER       1600 S OHIO ST      MARTINSVILLE    IN
# 8             FOOD 4 LESS   2420 COTTONWOOD DR         EL CENTRO    CA
# 9  WALMART GROCERY PICKUP     2460 E WABASH ST         FRANKFORT    IN
#
#    ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 0    26508  7005.0         61.0        304       2
# 1    92243  2619.0         25.0        760       2
# 2    92281     NaN         25.0        760       2
# 3    26505  3141.0         61.0        304       2
# 4    92281     NaN         25.0        760       2
# 5    92231  5917.0         25.0        760       2
# 6    92277  3129.0         71.0        760       2
# 7    46151  3317.0        109.0        765       2
# 8    92243  1604.0         25.0        760       2
# 9    46041  9429.0         23.0        765       2
#
#   LOCATION EMPLOYEE SIZE CODE LOCATION SALES VOLUME CODE  PRIMARY SIC CODE  \
# 0                           C                          C            541103
# 1                           B                          C            541103
# 2                           B                          C            541105
# 3                           A                          A            541105
# 4                           B                          C            541103
# 5                           D                          E            541105
# 6                           C                          D            541103
# 7                           F                          G            541105
# 8                           E                          F            541105
# 9                           A                          A            541110
#
#          SIC6_DESCRIPTIONS  PRIMARY NAICS CODE  \
# 0       CONVENIENCE STORES          44512001.0
# 1       CONVENIENCE STORES          44512001.0
# 2           GROCERS-RETAIL          44511003.0
# 3           GROCERS-RETAIL          44511003.0
# 4       CONVENIENCE STORES          44512001.0
# 5           GROCERS-RETAIL          44511003.0
# 6       CONVENIENCE STORES          44512001.0
# 7           GROCERS-RETAIL          44511003.0
# 8           GROCERS-RETAIL          44511003.0
# 9  GROCERY PICKUP-CURBSIDE                 NaN
#
#                                  NAICS8 DESCRIPTIONS  SIC CODE  \
# 0                                 CONVENIENCE STORES  554101.0
# 1                                 CONVENIENCE STORES  554101.0
# 2  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 3  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 4                                 CONVENIENCE STORES  554101.0
# 5  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  542107.0
# 6                                 CONVENIENCE STORES  554101.0
# 7  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 8  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 9                                                NaN       NaN
#
#            SIC6_DESCRIPTIONS (SIC)  SIC CODE 1 SIC6_DESCRIPTIONS (SIC1)  \
# 0  SERVICE STATIONS-GASOLINE & OIL    554110.0        ALTERNATIVE FUELS
# 1  SERVICE STATIONS-GASOLINE & OIL         NaN                      NaN
# 2                              NaN         NaN                      NaN
# 3                              NaN         NaN                      NaN
# 4  SERVICE STATIONS-GASOLINE & OIL         NaN                      NaN
# 5                      MEAT-RETAIL         NaN                      NaN
# 6  SERVICE STATIONS-GASOLINE & OIL    554110.0        ALTERNATIVE FUELS
# 7                              NaN         NaN                      NaN
# 8                              NaN         NaN                      NaN
# 9                              NaN         NaN                      NaN
#
#    SIC CODE 2 SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3 SIC6_DESCRIPTIONS(SIC3)  \
# 0         NaN                     NaN         NaN                     NaN
# 1         NaN                     NaN         NaN                     NaN
# 2         NaN                     NaN         NaN                     NaN
# 3         NaN                     NaN         NaN                     NaN
# 4         NaN                     NaN         NaN                     NaN
# 5         NaN                     NaN         NaN                     NaN
# 6         NaN                     NaN         NaN                     NaN
# 7         NaN                     NaN         NaN                     NaN
# 8         NaN                     NaN         NaN                     NaN
# 9         NaN                     NaN         NaN                     NaN
#
#    SIC CODE 4 SIC6_DESCRIPTIONS(SIC4)  ARCHIVE VERSION YEAR  YELLOW PAGE CODE  \
# 0         NaN                     NaN                  2022           21303.0
# 1         NaN                     NaN                  2022               NaN
# 2         NaN                     NaN                  2022           39106.0
# 3         NaN                     NaN                  2022           39106.0
# 4         NaN                     NaN                  2022               NaN
# 5         NaN                     NaN                  2022               NaN
# 6         NaN                     NaN                  2022               NaN
# 7         NaN                     NaN                  2022           39106.0
# 8         NaN                     NaN                  2022           39106.0
# 9         NaN                     NaN                  2022               NaN
#
#    EMPLOYEE SIZE (5) - LOCATION  SALES VOLUME (9) - LOCATION  \
# 0                          13.0                       2482.0
# 1                           6.0                       1273.0
# 2                           5.0                       1061.0
# 3                           2.0                        382.0
# 4                           6.0                       1273.0
# 5                          29.0                       6153.0
# 6                          10.0                       2631.0
# 7                         102.0                      21931.0
# 8                          70.0                      14851.0
# 9                           3.0                        439.0
#
#    BUSINESS STATUS CODE INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  \
# 0                     2                          NaN               NaN
# 1                     2                            W               NaN
# 2                     9                          NaN               NaN
# 3                     9                          NaN               NaN
# 4                     2                            F               NaN
# 5                     9                          NaN               NaN
# 6                     2                            A            2004.0
# 7                     2                            P               NaN
# 8                     2                          ï¿½               NaN
# 9                     2                            H               NaN
#
#    OFFICE SIZE CODE  COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  \
# 0               NaN                     NaN  998372387                NaN
# 1               NaN                     NaN  495660326                NaN
# 2               NaN                     NaN  519605455                NaN
# 3               NaN                     NaN  817953730                NaN
# 4               NaN                     NaN  855113817                NaN
# 5               NaN                     NaN  995912391                NaN
# 6               NaN                     NaN  547898643        425040557.0
# 7               NaN                     NaN  140765967                NaN
# 8               NaN                     NaN  215261702        402627138.0
# 9               NaN                     NaN  749097413        632353488.0
#
#    PARENT NUMBER  PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 0    124929449.0                         50.0                    389500.0
# 1      5863311.0                        800.0                   1272634.0
# 2            NaN                          NaN                         NaN
# 3            NaN                          NaN                         NaN
# 4    450720289.0                        650.0                   4981020.0
# 5            NaN                          NaN                         NaN
# 6      1490291.0                       5000.0                   7616641.0
# 7      7521503.0                       1200.0                 137888000.0
# 8      7521503.0                       1200.0                 137888000.0
# 9      5889993.0                      11000.0                 572754000.0
#
#   PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 0                         E                        I  998372387.0
# 1                         H                        K  495660326.0
# 2                       NaN                      NaN          NaN
# 3                       NaN                      NaN          NaN
# 4                         H                        J          NaN
# 5                       NaN                      NaN  995912391.0
# 6                         J                        K  547898643.0
# 7                         I                        I  140765967.0
# 8                         I                        I  215261702.0
# 9                         K                        K  492944806.0
#
#   ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 0                    NaN                7       11000.0           3.0
# 1                    NaN                7       11400.0           3.0
# 2                    NaN                3       10200.0           1.0
# 3                    NaN                7       10400.0           4.0
# 4                    NaN                3       10200.0           1.0
# 5                    NaN                7       12002.0           2.0
# 6                    NaN                7       10421.0           1.0
# 7                    NaN                7      510701.0           2.0
# 8                    NaN                7       11201.0           1.0
# 9                    NaN                7      950200.0           3.0
#
#     LATITUDE   LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 0  39.594376  -79.954437          P    34060.0         2.0     390.0
# 1  32.792679 -115.536058          0    20940.0         2.0       0.0
# 2  33.051800 -115.581800          X    20940.0         2.0       0.0
# 3  39.652885  -79.986398          P    34060.0         2.0     390.0
# 4  33.051800 -115.581800          X    20940.0         2.0       0.0
# 5  32.679923 -115.482166          P    20940.0         2.0       0.0
# 6  34.135287 -116.059794          P    40140.0         2.0     348.0
# 7  39.411880  -86.425148          P    26900.0         2.0     294.0
# 8  32.815719 -115.572166          P    20940.0         2.0       0.0
# 9  40.278905  -86.478737          P    23140.0         1.0     320.0
#
#    FIPS CODE
# 0    54061.0
# 1     6025.0
# 2     6025.0
# 3    54061.0
# 4     6025.0
# 5     6025.0
# 6     6071.0
# 7    18109.0
# 8     6025.0
# 9    18023.0

# %%
#Filter Grocery stores by sic (starting with 541105 & 531102)
grocery_sic = stores_2022.loc[stores_2022[['PRIMARY SIC CODE']].astype(str).apply(lambda x: x.str.startswith('541105')).any(axis=1)]
grocery_sic.head(10)
# Out:
#                   COMPANY           ADDRESS LINE 1          CITY STATE  \
# 2           EL SOL MARKET            110 W MAIN ST   WESTMORLAND    CA
# 3    COOL SPRINGS GROCERY          241 WILDWOOD ST    MORGANTOWN    WV
# 5      EL SOL MEAT MARKET      1100 MEADOWS RD # B      CALEXICO    CA
# 7                  KROGER           1600 S OHIO ST  MARTINSVILLE    IN
# 8             FOOD 4 LESS       2420 COTTONWOOD DR     EL CENTRO    CA
# 13                 KROGER        301 E MCKINLEY RD        OTTAWA    IL
# 14      WOODS SUPERMARKET       1407 W AUSTIN BLVD        NEVADA    MO
# 16             SKY MARKET  1904 E PALOMAR ST # 108   CHULA VISTA    CA
# 23    STATER BROS MARKETS    78630 HIGHWAY 111 # A     LA QUINTA    CA
# 27  KRAUSZER'S FOOD STORE             170 CEDAR ST      BRANFORD    CT
#
#     ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 2     92281     NaN         25.0        760       2
# 3     26505  3141.0         61.0        304       2
# 5     92231  5917.0         25.0        760       2
# 7     46151  3317.0        109.0        765       2
# 8     92243  1604.0         25.0        760       2
# 13    61350  4805.0         99.0        815       2
# 14    64772  2805.0        217.0        417       2
# 16    91913  5043.0         73.0        619       2
# 23    92253  2049.0         65.0        760       2
# 27     6405  6011.0          9.0        203       2
#
#    LOCATION EMPLOYEE SIZE CODE LOCATION SALES VOLUME CODE  PRIMARY SIC CODE  \
# 2                            B                          C            541105
# 3                            A                          A            541105
# 5                            D                          E            541105
# 7                            F                          G            541105
# 8                            E                          F            541105
# 13                           E                          F            541105
# 14                           E                          E            541105
# 16                           A                          B            541105
# 23                           F                          G            541105
# 27                           B                          C            541105
#
#    SIC6_DESCRIPTIONS  PRIMARY NAICS CODE  \
# 2     GROCERS-RETAIL          44511003.0
# 3     GROCERS-RETAIL          44511003.0
# 5     GROCERS-RETAIL          44511003.0
# 7     GROCERS-RETAIL          44511003.0
# 8     GROCERS-RETAIL          44511003.0
# 13    GROCERS-RETAIL          44511003.0
# 14    GROCERS-RETAIL          44511003.0
# 16    GROCERS-RETAIL          44511003.0
# 23    GROCERS-RETAIL          44511003.0
# 27    GROCERS-RETAIL          44511003.0
#
#                                   NAICS8 DESCRIPTIONS  SIC CODE  \
# 2   SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 3   SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 5   SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  542107.0
# 7   SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 8   SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 13  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 14  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  542107.0
# 16  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  539901.0
# 23  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS       NaN
# 27  SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS  581208.0
#
#        SIC6_DESCRIPTIONS (SIC)  SIC CODE 1 SIC6_DESCRIPTIONS (SIC1)  \
# 2                          NaN         NaN                      NaN
# 3                          NaN         NaN                      NaN
# 5                  MEAT-RETAIL         NaN                      NaN
# 7                          NaN         NaN                      NaN
# 8                          NaN         NaN                      NaN
# 13                         NaN         NaN                      NaN
# 14                 MEAT-RETAIL    546102.0            BAKERS-RETAIL
# 16  GENERAL MERCHANDISE-RETAIL         NaN                      NaN
# 23                         NaN         NaN                      NaN
# 27                 RESTAURANTS    541103.0       CONVENIENCE STORES
#
#     SIC CODE 2 SIC6_DESCRIPTIONS(SIC2)  SIC CODE 3 SIC6_DESCRIPTIONS(SIC3)  \
# 2          NaN                     NaN         NaN                     NaN
# 3          NaN                     NaN         NaN                     NaN
# 5          NaN                     NaN         NaN                     NaN
# 7          NaN                     NaN         NaN                     NaN
# 8          NaN                     NaN         NaN                     NaN
# 13         NaN                     NaN         NaN                     NaN
# 14    591205.0              PHARMACIES    592102.0          LIQUORS-RETAIL
# 16         NaN                     NaN         NaN                     NaN
# 23         NaN                     NaN         NaN                     NaN
# 27         NaN                     NaN         NaN                     NaN
#
#     SIC CODE 4 SIC6_DESCRIPTIONS(SIC4)  ARCHIVE VERSION YEAR  \
# 2          NaN                     NaN                  2022
# 3          NaN                     NaN                  2022
# 5          NaN                     NaN                  2022
# 7          NaN                     NaN                  2022
# 8          NaN                     NaN                  2022
# 13         NaN                     NaN                  2022
# 14         NaN                     NaN                  2022
# 16         NaN                     NaN                  2022
# 23         NaN                     NaN                  2022
# 27         NaN                     NaN                  2022
#
#     YELLOW PAGE CODE  EMPLOYEE SIZE (5) - LOCATION  \
# 2            39106.0                           5.0
# 3            39106.0                           2.0
# 5                NaN                          29.0
# 7            39106.0                         102.0
# 8            39106.0                          70.0
# 13           39106.0                          70.0
# 14           39106.0                          63.0
# 16               NaN                           3.0
# 23           39106.0                         130.0
# 27               NaN                           8.0
#
#     SALES VOLUME (9) - LOCATION  BUSINESS STATUS CODE  \
# 2                        1061.0                     9
# 3                         382.0                     9
# 5                        6153.0                     9
# 7                       21931.0                     2
# 8                       14851.0                     2
# 13                      14158.0                     2
# 14                       9332.0                     2
# 16                        543.0                     9
# 23                      37123.0                     2
# 27                       1927.0                     2
#
#    INDUSTRY SPECIFIC FIRST BYTE  YEAR ESTABLISHED  OFFICE SIZE CODE  \
# 2                           NaN               NaN               NaN
# 3                           NaN               NaN               NaN
# 5                           NaN               NaN               NaN
# 7                             P               NaN               NaN
# 8                           ï¿½               NaN               NaN
# 13                            P               NaN               NaN
# 14                          NaN               NaN               NaN
# 16                          NaN            2017.0               NaN
# 23                            {               NaN               NaN
# 27                          ï¿½               NaN               NaN
#
#     COMPANY HOLDING STATUS        ABI  SUBSIDIARY NUMBER  PARENT NUMBER  \
# 2                      NaN  519605455                NaN            NaN
# 3                      NaN  817953730                NaN            NaN
# 5                      NaN  995912391                NaN            NaN
# 7                      NaN  140765967                NaN      7521503.0
# 8                      NaN  215261702        402627138.0      7521503.0
# 13                     NaN  152123287                NaN      7521503.0
# 14                     NaN  452808512                NaN    834898306.0
# 16                     NaN  724918224                NaN            NaN
# 23                     NaN  469247928        987328788.0    861921039.0
# 27                     NaN  489185330                NaN    441482742.0
#
#     PARENT ACTUAL EMPLOYEE SIZE  PARENT ACTUAL SALES VOLUME  \
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 5                           NaN                         NaN
# 7                        1200.0                 137888000.0
# 8                        1200.0                 137888000.0
# 13                       1200.0                 137888000.0
# 14                         20.0                     48500.0
# 16                          NaN                         NaN
# 23                         50.0                   1047300.0
# 27                        100.0                     48500.0
#
#    PARENT EMPLOYEE SIZE CODE PARENT SALES VOLUME CODE  SITE NUMBER  \
# 2                        NaN                      NaN          NaN
# 3                        NaN                      NaN          NaN
# 5                        NaN                      NaN  995912391.0
# 7                          I                        I  140765967.0
# 8                          I                        I  215261702.0
# 13                         I                        I  152123287.0
# 14                         D                        G  452808512.0
# 16                       NaN                      NaN          NaN
# 23                         E                        K          NaN
# 27                         F                        G          NaN
#
#    ADDRESS TYPE INDICATOR  POPULATION CODE  CENSUS TRACT  CENSUS BLOCK  \
# 2                     NaN                3       10200.0           1.0
# 3                     NaN                7       10400.0           4.0
# 5                     NaN                7       12002.0           2.0
# 7                     NaN                7      510701.0           2.0
# 8                     NaN                7       11201.0           1.0
# 13                    NaN                7      963500.0           1.0
# 14                    NaN                6      950300.0           5.0
# 16                    NaN                7       13313.0           1.0
# 23                    NaN                7       45215.0           3.0
# 27                    NaN                7      184700.0           3.0
#
#      LATITUDE   LONGITUDE MATCH CODE  CBSA CODE  CBSA LEVEL  CSA CODE  \
# 2   33.051800 -115.581800          X    20940.0         2.0       0.0
# 3   39.652885  -79.986398          P    34060.0         2.0     390.0
# 5   32.679923 -115.482166          P    20940.0         2.0       0.0
# 7   39.411880  -86.425148          P    26900.0         2.0     294.0
# 8   32.815719 -115.572166          P    20940.0         2.0       0.0
# 13  41.323858  -88.836271          P    36837.0         1.0     176.0
# 14  37.836468  -94.374786          P        0.0         NaN       0.0
# 16  32.626419 -116.975922          P    41740.0         2.0       0.0
# 23  33.715244 -116.293300          P    40140.0         2.0     348.0
# 27  41.289936  -72.819829          P    35300.0         2.0     408.0
#
#     FIPS CODE
# 2      6025.0
# 3     54061.0
# 5      6025.0
# 7     18109.0
# 8      6025.0
# 13    17099.0
# 14    29217.0
# 16     6073.0
# 23     6065.0
# 27     9009.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
pd.set_option('display.max_columns', None)
from shapely.geometry import Point
import fiona
import math
import plotly.express as px
from thefuzz import fuzz
from thefuzz import process
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Create lists of Supermarkets/Companies owned by the Parent Coporations of Interest (Supermarkets/Companies were taken from Wikipedia)

#Ahold Delhaize owned supermarkets/companies
ahold = ["Bottom Dollar Food",
    "Food Lion",
    "FreshDirect",
    "Giant",
    "Giant Food",
    "Hannaford",
    "Stop & Shop",
    "Peapod",
    "Bfresh",
    "Eastside Marketplace",]

#WALMART owned supermarkets/companies
walmart = ["WALMART","SAM'S CLUB"]

#Krogers owned supermarkets/companies
kroger = ["Baker's",
    "City Market",
    "Dillons",
    "Food 4 Less",
    "Foods Co.",
    "Fred Meyer",
    "Fry's",
    "Gerbes",
    "Harris Teeter",
    "JayC",
    "King Soopers",
    "Kroger",
    "Mariano's",
    "Metro Market",
    "Pay Less",
    "Pick 'n Save",
    "QFC",
    "Ralphs",
    "Ruler Foods",
    "Smith's",]

# Albertsons owned supermarkets/companies
albertsons= ["Acme Markets",
    "Albertsons",
    "Albertsons Market",
    "Amigos",
    "Andronico's",
    "Balducci's",
    "Carrs",
    "Haggen",
    "Jewel-Osco",
    "Kings Food Markets",
    "Lucky",
    "Market Street",
    "Pak 'n Save",
    "Pavilions",
    "Randalls",
    "Safewa",
    "Shaw's",
    "Star Market",
    "Tom Thumb",
    "United Supermarkets",
    "Vons",
    "Buttrey Food and Drug",
    "Max Food and Drug",
    "Max Foods",
    "Skagg's Albertsons",
    "Super Saver",]

#Costco owned supermarkets/companies
costco = ["Costco"]

# %%
#Generated String Matches from above

#String matched brands owned by Walmart:
walmart_string = ['WALMART GROCERY PICKUP', 'WALMART GROCERY PKUP-DELIVERY', "SAM'S CLUB DELI"]

#String matched brands owned by Ahold Delhaize:
ahold_string = ['BOTTOM DOLLAR', 'DOLLAR DOLLAR', 'FOOD', 'FOOD 4 LESS', 'FOOD LION', 'FRESH DIRECT', 'REC', 'FRESH', 'H & H', 'S & S', 'FRESHII', 'GIANT', 'GIANT EAGLE', 'GIANT EAGLE FLORAL', 'GIANT FOOD', 'HANNAFORD', 'STOP & SHOP', 'PEA POD', 'BFRESH MARKET', 'REFRESH', 'EASTSIDE MARKETPLACE', 'WESTSIDE MARKETPLACE', 'MARKET', 'E MARKET', 'MARKETPLACE']

#String matched brands owned by Kroger:
kroger_string = ["BAKER'S", 'S & S', 'BAKERS', "BAKER'S GAS & WELD SUPLS INC", "BAKER'S GAS", "BAKER'S MARKET", "BAKER'S PRO FARM LLC", 'BAKER STREET MARKET', "BAKER'S KWIK SHOP", 'CITY MARKET', 'DILLONS', 'FOOD 4 LESS', 'FOODS CO', 'FRED MEYER', "FRY'S FOOD", 'GERBES SUPER MARKET', 'GERBES SUPER MARKETS', 'GE', 'GERBES SUPERMARKET', 'HARRIS TEETER', 'JAYC', "JAYCEE'S", 'JAYCON', 'CITY-RALEIGH-JAYCEE PARK-CMNTY', 'JAYCE MINIMARKET', 'NAY & JAY', 'KING SOOPERS', 'KROGER', "MARIANO'S", 'METRO MARKET', 'METRO MINI MARKET', 'MARKET MARKET', 'PAY LESS LIQUORS', 'PAY LESS SUPER MARKETS', 'PAY LESS GAS & FOOD', 'PAY LESS IGA', 'FOOD FOR LESS', 'FAR LESS FOOD MARKET', 'MORE FOR LESS', 'PRICE LESS FOODS', 'COST LESS FOODS CO', "PICK'N SAVE", 'QFC', 'RALPHS', 'RULER FOODS', "SMITH'S"]

#String matched brands owned by Costco
costco_string = ["COSTCO DELI"]

#String matched brands owned by Albertsons
albertsons_string = ['ACME MARKETS', 'ALBERTSONS', 'ALBERTSONS MARKET', 'MARKET MARKET', 'MARKET', '2 AMIGOS', 'AMIGO', 'LOS AMIGOS DISTRIBUTING', 'DOS AMIGOS MARKET', '3 AMIGOS BEER WINE-FOOD STORE', 'THREE AMIGOS', 'AMIGOS FOOD MART', 'LOS AMIGOS', 'AMIGOS MKT LOS', 'AMIGOS MARKET 7', 'TIENDA LOS AMIGOS', 'AMIGOS CONVENIENCE STORE', 'LOS AMIGOS UNO', 'AMIGOS LATIN GROCERY', 'AMIGOS UNITED', 'AMIGOS FOOD MART LLC', 'LOS AMIGOS MARKET', 'LOS AMIGOS SUPERMARKET', 'ICO', "ANDRONICO'S COMMUNITY MARKETS", "KRAUSZER'S FOOD STORE", "CASEY'S", "MR T'S", "SEVEN'S", "PATTY'S PANTRY & DELI", "CASHION'S QUIK STOP", 'E C F S SNACKS LLC', "MICKEY'S T-MART INC", "STATLER'S COUNTRY MART", "MIKE'S CONVENIENCE", "BELL'S ROWLESBURG GROCERY", "SOCCORSI'S GROCERY & SUBS", 'CC', "BALDUCCI'S FOOD LOVER'S MARKET", "DANIEL'S MARKET", "GRILLO'S MARKET", 'S & G CONVENIENCE MART', "NANCY'S FOODMART", "MILLER'S MARKETS", "MAYNARD'S OF FLANDREAU", "SKIP'S", "HARDESTY'S EXPRESS MART LLC", "KASSAR'S FOOD & GIFTS", "JERRY'S MARKET & LIQUOR", "SHELLY'S GROCERY & BAKERY LLC", 'CARRS/SAFEWAY', 'CARRS SAFEWAY', 'CARRS QUALITY CTR PALMER SHPG', 'BIG CHEAP CASH & CARR', 'C & B USED CARS', 'HAGGEN', 'HAGGEN FOOD & PHARMACY', 'HAGGEN SUPPORT CTR', 'HAGGEN FOOD', 'GE', 'JEWEL-OSCO', 'KINGS FOOD MARKETS', 'KINGS FOOD MARKET', "KING'S FOOD MARKET", "KING'S FOODMARKET", 'KINGS FOOD MART', 'FOOD', 'LUCKY', 'LUCKY 3', 'LUCKY 7', "LUCKY'S", 'LUCKY 8', 'LUCKYS', 'LUCKY SEVEN FOOD STORE', 'LUCKY FOOD FARMERS MARKET', 'LUCKY GROCERY & DELI', 'LUCKY DOLLAR', 'LUCKY CHARM CONVENIENCE STORE', 'LUCKY STAR MARKET LLC', 'LUCKY FOOD MART LLC', 'LUCKY MARKET', "LUCKY'S STATION", 'LUCKY MARKET LLC', "LUCKY'S SUPER MARKET", 'MARKET STREET', "PAK 'N SAVE", 'U-SAVE FOOD STORE', 'GOLD LINE GRAB N GO', 'INDO PAK SUPERMARKET', 'STOP N GO FOOD MART', 'STOP N GO ENTERPRISES INC', "OCALA SHOP N' PLAY LLC", 'J & N MINI MART 2', "GRAB 'N GO MART LLC", 'KWIK PAK FOOD MART', "SHOP 'N SAVE EXPRESS", 'PIC-N-SAVE MARKET', 'U-SAVE TRAVEL PLAZA', "UP NORT' SWEET N SAVORY", 'STOP N SHOP WESTFIELD', "SACK 'N SAVE FOOD", "STOP 'N GO MARKETS OF TEXAS", 'CARTA N SHORE GARAGE', 'MASALA INDO PAK GROCERS', 'IN N OUT FOOD & GAS LLC', "GAS 'N' GO FOOD & BEVERAGE", 'N A M C COMMUNITY MARKET INC', 'PAVILIONS', 'RANDALLS', 'SAFEWAY', 'S & S', "SHAW'S SUPERMARKET", "SHAW'S SUPERMARKETS INC", 'STAR MARKET', 'TOM THUMB', 'UNITED SUPERMARKETS', 'VONS', 'FOOD 4 LESS', 'FOOD MART', 'FOOD LION', 'HERA FOOD MART', 'FOOD TOWN', 'FOOD FAIR', 'OHM FOOD MART', "D'S FOOD STORE", 'FOOD EXPRESS', 'E Z FOOD MART', 'JR FOOD MART', 'EXPRESS FOOD', 'MR FOOD MART', 'CITGO CONVENIENT FOOD MART', 'GREEN ACRES HEALTH FOOD STORE', 'FRIENDSHIP FOOD STORES INC', 'VERISTAS AFRICAN FOOD STORE', 'ILLINOIS VALLEY FOOD & DELI', "FRY'S FOOD", 'FOOD CITY', 'MAX FOODS', 'MAXI FOODS', 'FOODS', 'FOOD MAX', 'SUPER ONE FOODS', 'SUNSHINE FOODS', 'JAMBOREE FOODS', 'DAY STAR FOODS', "SULLIVAN'S FOODS", 'AFFILIATED FOODS CO-OP', "JENSEN'S FINEST FOODS", 'EAST DAKOTAH NATURAL FOODS', "JENSEN'S FOODS", 'RITE PRICE FOODS', 'VALLEY CENTER FOODS', 'SUPER SAVER', 'SUPER SAVE', 'SUPER SAVER INC', 'SUPER', 'SUPER SAVER COST PLUS', "SAAR'S SUPER SAVER FOODS"]

# %%
#Cleaned lists from the string matches of supermarkets/companies actually owned by the parent coprporation
#***NOTE***There will be a margin of error from this process because stores were validated through manual checks
#***NOTE***It was unrealistic to manually inspect every store generated this way so there will be supermarkets/companies that do not actually belong to the parent coporation

#KROGERS FINAL
kroger_clean = ["BAKER'S",
 'BAKERS', 
 'CITY MARKET',
 'DILLONS',
 'FOOD 4 LESS', 
 'FOODS CO', 
 'FRED MEYER', 
 "FRY'S FOOD",
 'GERBES SUPER MARKET',  
 'GERBES SUPER MARKETS', 
 'GERBES SUPERMARKET', 
 'HARRIS TEETER', 
 'JAYC', 
 'KING SOOPERS',
 'KROGER',
 "MARIANO'S",
 'METRO MARKET', 
 'PAY LESS SUPER MARKETS',
 "PICK'N SAVE", 
 'QFC', 
 'RALPHS', 
 'RULER FOODS', 
 "SMITH'S"]

#Ahold Delhaize FINAL:
ahold_clean = ['BOTTOM DOLLAR',
 'FOOD LION',
 'GIANT',
 'GIANT EAGLE',
 'GIANT FOOD',
 'HANNAFORD',
 'STOP & SHOP',
 'PEA POD',
 'BFRESH MARKET',
 'EASTSIDE MARKETPLACE']

#WALMART FINAL:
walmart_clean = ['WALMART GROCERY PICKUP',
 'WALMART GROCERY PKUP-DELIVERY', 
 "SAM'S CLUB DELI"]

#COSTCO FINAL:
costco_clean = ["COSTCO DELI"]

#ALBERTSONS FINAL:
albertsons_clean = ['ACME MARKETS',
'ALBERTSONS',
'ALBERTSONS MARKET',
'2 AMIGOS',
'AMIGOS UNITED',
'LOS AMIGOS MARKET',
'LOS AMIGOS SUPERMARKET',
"ANDRONICO'S COMMUNITY MARKETS",
'CARRS/SAFEWAY',
'CARRS SAFEWAY',
'HAGGEN',
'HAGGEN FOOD & PHARMACY',
'HAGGEN FOOD',
'JEWEL-OSCO',
'KINGS FOOD MARKETS',
'KINGS FOOD MARKET',
'MARKET STREET',
"PAK 'N SAVE",
'PAVILIONS',
'RANDALLS',
'SAFEWAY',
'STAR MARKET',
'TOM THUMB',
'UNITED SUPERMARKETS',
'VONS',
'MAX FOODS',
'MAXI FOODS',
'SUPER SAVER',
'SUPER SAVE',
'SUPER SAVER COST PLUS',
'CARRS QUALITY CTR PALMER SHPG',
 "SAAR'S SUPER SAVER FOODS"]

# %%
#Records the removed values from the string matching for each store
#"Removed" list can be used to see the values we chose to remove from the string match
kroger_removed = [value for value in kroger_string if value not in kroger_clean]
ahold_removed = [value for value in ahold_string if value not in ahold_clean]
walmart_removed = [value for value in walmart_string if value not in walmart_clean]
costco_removed = [value for value in costco_string if value not in costco_clean]
albertsons_removed = [value for value in albertsons_string if value not in albertsons_string]

# %%
def parent_name(row):
    '''Creates a new column called "PARENT NAME" based on the cleaned string match list''' 
    '''The new column generalizes individual companies into their parent coporation (ie. Walmart, Krogers, etc.)''' 
    companies = row['COMPANY']  
    
    if companies in walmart_clean:
        return 'WALMART'
    if companies in costco_clean:
        return 'COSTCO'
    if companies in ahold_clean:
        return 'AHOLD'
    if companies in kroger_clean:
        return 'KROGER'
    if companies in albertsons_clean:
        return 'ALBERTSONS'
    else:
        return 'OTHER'

stores_2022['PARENT NAME'] = stores_2022.apply(parent_name, axis=1)

# %%
#Locate the unique primary sic codes present within the supermarkets/companies owned by the parent corporations of interest
#These unique primary SIC codes will be used as the basis of how we filter the main dataset to include only relevant supermarkets/companies (ie. removing convenient stores)

#Step 1: Filter a dataframe based on parent coporations
parent_companies = ['WALMART', 'COSTCO', 'KROGER', 'AHOLD','ALBERTSONS']
filtered_df = stores_2022[stores_2022['PARENT NAME'].isin(parent_companies)]

# Step 2: Extract the PRIMARY SIC CODES values
primary_sic_codes = filtered_df['PRIMARY SIC CODE']

# Step 3: Get the unique PRIMARY SIC CODES values
unique_sic_codes = primary_sic_codes.unique()

# Print the unique PRIMARY SIC CODES
unique_sic_codes = np.delete(unique_sic_codes,(np.where(unique_sic_codes == 541103)))

#***NOTE remove SIC Code 541103 since it contains the SIC code for convenient stores

# %%
'''parent = costco
companies = stores_2022["COMPANY"]

matches = []
for item in parent:
    #for result in process.contains(item, companies, limit=len(parent)+1):
    for result in process.extract(item, companies, limit=200000):
        store = result[0]
        score = result[1]
        if score >= 77 and store not in matches:
            matches.append(store)

print(matches) '''
# Out:
# 'parent = costco\ncompanies = stores_2022["COMPANY"]\n\nmatches = []\nfor item in parent:\n    #for result in process.contains(item, companies, limit=len(parent)+1):\n    for result in process.extract(item, companies, limit=200000):\n        store = result[0]\n        score = result[1]\n        if score >= 77 and store not in matches:\n            matches.append(store)\n\nprint(matches) '

# %%
len(parent)
# Out:
# 6

# %%
query = 'geeks for geeks'
choices = ['geek for geek', 'geek geek', 'g. for geeks', 'geek', 'eeek', 'nah'] 
   
# Get a list of matches ordered by score, default limit to 5
test = process.extract(query, choices, limit=6)

# %%
for example in test:
    print(example[1])
# Out:
# 95
# 93
# 90
# 86
# 68
# 0

# %%
query = 'STOP & SHOP'
choices = ['STOP & SHOP GROCERY', 'STOP & SHOP MARKET'
          ] 
   
# Get a list of matches ordered by score, default limit to 5
process.extract(query, choices, limit=6)
# Out:
# [('STOP & SHOP GROCERY', 90), ('STOP & SHOP MARKET', 90)]

# %%
#Apply a string match through thefuzz that compares all stores to the parent corporations owned stores
#We decided to use a threshold of 77 because it is how similar it should be in order to be pulled.
#Generates a list of potential unique string matches
#The matches list's length is based on the number of different stores the parent corporation owns
#parent was initialized for each parent coporation (finished at costco)
'''
testone = ['Stop and Shop']
input_list = stores_2022["COMPANY"]

matches = []
for item in testone:
    for result in process.extract(item,input_list, limit=len(input_list)):
        store = result[0]
        score = result[1]
        if score >= 80 and store not in matches:
            matches.append(store)

print(matches)'''
# Out:
# '\ntestone = [\'Stop and Shop\']\ninput_list = stores_2022["COMPANY"]\n\nmatches = []\nfor item in testone:\n    for result in process.extract(item,input_list, limit=len(input_list)):\n        store = result[0]\n        score = result[1]\n        if score >= 80 and store not in matches:\n            matches.append(store)\n\nprint(matches)'

# %%
'''parent = costco
companies = stores_2022["COMPANY"]

matches = []
for item in parent:
    #for result in process.contains(item, companies, limit=len(parent)+1):
    #for result in process.extract(item, companies, limit=200000):
        store = result[0]
        score = result[1]
        if score >= 77 and store not in matches:
            matches.append(store)

print(matches) '''
# Out:
# 'parent = costco\ncompanies = stores_2022["COMPANY"]\n\nmatches = []\nfor item in parent:\n    #for result in process.contains(item, companies, limit=len(parent)+1):\n    #for result in process.extract(item, companies, limit=200000):\n        store = result[0]\n        score = result[1]\n        if score >= 77 and store not in matches:\n            matches.append(store)\n\nprint(matches) '

# %%
#Apply a string match through thefuzz that compares all stores to the parent corporations owned stores
#We decided to use a threshold of 77 because it is how similar it should be in order to be pulled.
#Generates a list of potential unique string matches
#The matches list's length is based on the number of different stores the parent corporation owns
#parent was initialized for each parent coporation (finished at costco)

testone = ['Stop and Shop']
input_list = stores_2022["COMPANY"]

matches = []
for item in testone:
    for result in process.contains(item,input_list, limit=len(input_list)):
        store = result[0]
        score = result[1]
        if score >= 80 and store not in matches:
            matches.append(store)

print(matches)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 12
#      10 matches = []
#      11 for item in testone:
# ---> 12     for result in process.contains(item,input_list, limit=len(input_list)):
#      13         store = result[0]
#      14         score = result[1]
#
# AttributeError: module 'thefuzz.process' has no attribute 'contains'

# %% [markdown]
# # Updated
# **String Matching progress made with Mario**
#  using .contains rather than .extract

# %%
parent = walmart
companies = stores_2022["COMPANY"]
companies

x = companies.str.contains('walmart',case=False)
x.loc[lambda x: x ==True].index

companies[9]

matches = []
for item in parent: #for each company owned by the parent,do the following:
    #print(item)
    
    stcon = companies. str. contains (item, case=False) #check if item is contained in companies (item represents each company owned)

    index_match = stcon. loc [lambda x: x == True]. index #takes the location of the string matches if close

    for result in index_match: #now that we know the matches, add the simiar ones into the array
        #print (result)
        if companies[result] not in matches:
            #print (companies [result))
            matches. append (companies [result]) #adds into the array
            print (matches)

# %%
walmart_companies = matches
walmart_companies

# %%
matches = []
for item in parent: #for each company owned by the parent,do the following:
    #print(item)
    
    stcon = companies. str. contains (item, case=False) #check if item is contained in companies (item represents each company owned)

    index_match = stcon. loc [lambda x: x == True]. index #takes the location of the string matches if close

    for result in index_match: #now that we know the matches, add the simiar ones into the array
        #print (result)
        if companies[result] not in matches:
            #print (companies [result))
            matches. append (companies [result]) #adds into the array
            print (matches)

# %%
matches

# %%
stores_2022.loc[~stores_2022["COMPANY"].isin(matches)]["

# %%
important naics codes for filtering: 44511003 (costco/walmart); important sic codes: 541110, 541105 (walmart)

# %%
walmarts = stores_2022.loc[stores_2022["COMPANY"].isin(matches)]
walmarts

# %% [markdown]
# # TO DO:
# -Use kenthia's NAICS CODEs/FILTER to filter DATASET dataframe (main dataset with every store (not just supermarkets)) ✅
#
# -Add walmarts dataframe to NAICS filtered dataframe
#
#   -Drop duplicates if neceessary

# %%
#filter by NAICS code "44511" - SUPERMARKETS/OTHER GROCERY (EXC CONVENIENCE) STRS

#grocery_naics = stores_2022.loc[(stores_2022["PRIMARY NAICS CODE"] == 445110) | (stores_2022["PRIMARY NAICS CODE"] == 455219 ) | (stores_2022["PRIMARY NAICS CODE"] == 452311) ]

'''grocery_naics = stores_2022.loc[stores_2022[['PRIMARY NAICS CODE']].astype(str).apply(lambda x: x.str.startswith('44511')).any(axis=1)]
grocery_naics (this is the working code that filters by NAICS )'''

naics = stores_2022.loc[stores_2022[['PRIMARY NAICS CODE']].astype(str).apply(lambda x: x.str.startswith('44511')).any(axis=1)]
naics

naics_codes = naics["PRIMARY NAICS CODE"].unique()
# There are 75043 supermarkets/related companies in the entire US

# %%
naics_codes

# %%
naics = stores_2022.loc[stores_2022[['PRIMARY NAICS CODE']].astype(str).apply(lambda x: x.str.startswith('44511')).any(axis=1)]
naics

naics_codes = naics["PRIMARY NAICS CODE"].unique()
stores = pure.loc[(pure["PRIMARY NAICS CODE"].isin(naics_codes)) | (pure["COMPANY"].isin(walmart_companies))]
stores.shape

# %%
"""#CompleteDataset = pd.merge(walmarts, dataset)
#CompleteDataset
merged_df = walmarts.merge(dataset, on='COMPANY', how='outer')
merged_df

import pandas as pd

merged_data = pd.merge(walmart, dataset, on="PRIMARY SIC CODE", how='outer')
merged_data

walmarts_and_datasets = pd.merge(walmarts,datasets,how = "left", on = ["PRIMARY SIC CODE"])
walmarts_and_datasets.head()

stores= dataset.loc[dataset]company].isin(walmart) """

# %%
import pandas as pd

walmarts_and_dataset=pd.merge(walmarts,dataset,how="left",on=["PRIMARY NAICS CODE"])
walmarts_and_dataset

# %%
walmarts["PRIMARY SIC CODE"].unique()

# %%
stores_2022.loc[stores_2022["PRIMARY SIC CODE"] == 541105]

# %% [markdown]
# # experimenting with the string match
#
#
# when loading more than one string match its says
#
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.

# %%
parent = "walmart"
companies = stores_2022["COMPANY"]
companies

# %%
x = companies.str.contains('walmart',case=False)
x.loc[lambda x: x ==True].index

# %%
matches = []
for item in parent: #for each company owned by the parent,do the following:
    #print(item)
    
    stcon = companies. str. contains (item, case=False) #check if item is contained in companies (item represents each company owned)

    index_match = stcon. loc [lambda x: x == True]. index #takes the location of the string matches if close

    for result in index_match: #now that we know the matches, add the simiar ones into the array
        #print (result)
        if companies[result] not in matches:
            #print (companies [result))
            matches. append (companies [result]) #adds into the array
            print (matches)

# %% [markdown]
# # New work progress!
#
#
#  **Problems:**
#
# the code string matches companies that are similar in name, but also companies that aren't owned by the parent company, for kroger, albertsons, and alholds
#
# For costco & walmart the code works because all of the companies that they own has the parent name listed
#
# For costco & walmart find their NAICS CODES!!
#
# to fix this we are using the grocery_sic dataframe because it is already seperated by SIC codes, so that we would get more accurate searches that only contain grocery stores

# %%
#Filter Grocery stores by sic (starting with 541105 541110)(44511 NAICS)
grocery_sic = stores_2022.loc[stores_2022[['PRIMARY SIC CODE', 'SIC CODE', 'SIC CODE 1', 'SIC CODE 2', 'SIC CODE 3', 'SIC CODE 4']].astype(str).apply(lambda x: x.str.startswith('5411')).any(axis=1)]
grocery_sic

# %%
grocery_only = grocery_sic[['PRIMARY SIC CODE'] == '541105' or '541110']
grocery_only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 grocery_only = grocery_sic[['PRIMARY SIC CODE'] == '541105' or '541110']
#       2 grocery_only
#
# NameError: name 'grocery_sic' is not defined

# %%
#Filter Grocery stores by sic (starting with 541105 541110)(44511 NAICS)
grocery_sic = stores_2022.loc[stores_2022[['PRIMARY SIC CODE']].astype(str).apply(lambda x: x.str.loc('5411')).any(axis=1)]
grocery_sic

# %%
parent = "kroger"
grocery = grocery_sic['PRIMARY SIC CODE'] 
grocery

x = grocery.str.contains('kroger',case=False)
x.loc[lambda x: x ==True].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 parent = "kroger"
# ----> 2 grocery = grocery_sic['PRIMARY SIC CODE']
#       3 grocery
#       5 x = grocery.str.contains('kroger',case=False)
#
# NameError: name 'grocery_sic' is not defined

# %%
matches = []
for item in parent: #for each company owned by the parent,do the following:
    #print(item)
    
    stcon = grocery.str.contains(item, case=False) #check if item is contained in grocery (item represents each company owned)

    index_match = stcon.loc[lambda x: x == True].index #takes the location of the string matches if close

    for result in index_match: #now that we know the matches, add the simiar ones into the array
        #print (result)
        if grocery_sic[result] not in matches:
            #print (companies [result))
            matches.append(grocery[result]) #adds into the array
            print (matches)

# %% [markdown]
# # CLEAN

# %%
parent = "walmart"

x = pure.COMPANY.str.contains('walmart',case=False)
x.loc[lambda x: x ==True].index

walmarts = []
for item in parent: #for each company owned by the parent,do the following:
    #print(item)
    
    stcon = companies. str. contains (item, case=False) #check if item is contained in companies (item represents each company owned)

    index_match = stcon. loc [lambda x: x == True]. index #takes the location of the string matches if close

    for result in index_match: #now that we know the matches, add the simiar ones into the array
        #print (result)
        if companies[result] not in walmart:
            #print (companies [result))
            walmart. append (companies [result]) #adds into the array
            print (walmart)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       6 walmarts = []
#       7 for item in parent: #for each company owned by the parent,do the following:
#       8     #print(item)
# ---> 10     stcon = companies. str. contains (item, case=False) #check if item is contained in companies (item represents each company owned)
#      12     index_match = stcon. loc [lambda x: x == True]. index #takes the location of the string matches if close
#      14     for result in index_match: #now that we know the matches, add the simiar ones into the array
#      15         #print (result)
#
# NameError: name 'companies' is not defined

# %%
parent = walmart
companies = dataset["COMPANY"]
companies

x = companies.str.contains('walmart',case=False)
x.loc[lambda x: x ==True].index

companies[9]

matches = []
for item in parent: #for each company owned by the parent,do the following:
    #print(item)
    
    stcon = companies. str. contains (item, case=False) #check if item is contained in companies (item represents each company owned)

    index_match = stcon. loc [lambda x: x == True]. index #takes the location of the string matches if close

    for result in index_match: #now that we know the matches, add the simiar ones into the array
        #print (result)
        if companies[result] not in matches:
            #print (companies [result))
            matches. append (companies [result]) #adds into the array
            print (matches)

# %%
def find_matches(parent, companies):
    matches = []
    for item in parent:
        stcon = companies.str.contains(item, case=False) 
        index_match = stcon.loc[lambda x: x == True].index 

        for result in index_match:
            if companies[result] not in matches:
                matches.append(companies[result])

    return matches

# Use the function
parent = walmart
companies = dataset["COMPANY"]
matches = find_matches(parent, companies)
print(matches)
# Out:
# ['WALMART GROCERY PICKUP', 'WALMART GROCERY PKUP-DELIVERY', 'WALMART NEIGHBORHOOD MARKET', 'WALMART PICKUP-DELIVERY', 'WALMART GROCERY PICKUP # 2627', 'WALMART PICKUP & DELIVERY', 'WALMART GROCERY PICKYP-DLVRY', 'WALMART PICKUP-DELIVERY AT VA', "SAM'S CLUB DELI"]

# %%
naics = pure.loc[pure[['PRIMARY NAICS CODE']].astype(str).apply(lambda x: x.str.startswith('44511')).any(axis=1)]
naics

naics_codes = naics["PRIMARY NAICS CODE"].unique()

stores = pure.loc[(pure["PRIMARY NAICS CODE"].isin(naics_codes)) | (pure["COMPANY"].isin(walmart_companies))]
stores.shape
# Out:
# (79709, 53)

# %%
naics = pure.loc[pure.loc[:, ['PRIMARY NAICS CODE']].astype(str).apply(lambda x: x.str.startswith('44511')).any(axis=1)]
naics["PRIMARY NAICS CODE"].unique()
# Out:
# array([44511003., 44511006., 44511007., 44511004.])

# %% [markdown]
# # July 15th

# %%
grocery_sic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 grocery_sic
#
# NameError: name 'grocery_sic' is not defined

# %% [markdown]
# # July 17th
# **read in census data
#
# find counties for la and chicago
#
# most populated counties
#
# then create visualizations

# %%
census_data = pd.read_csv('../rafi-grocery/data/census/acs_census_2021.csv')

census_data
# Out:
#       Unnamed: 0          geo_id                       census_name  \
# 0              0  0500000US01001           Autauga County, Alabama
# 1              1  0500000US01003           Baldwin County, Alabama
# 2              2  0500000US01005           Barbour County, Alabama
# 3              3  0500000US01007              Bibb County, Alabama
# 4              4  0500000US01009            Blount County, Alabama
# ...          ...             ...                               ...
# 3216        3216  0500000US72145  Vega Baja Municipio, Puerto Rico
# 3217        3217  0500000US72147    Vieques Municipio, Puerto Rico
# 3218        3218  0500000US72149   Villalba Municipio, Puerto Rico
# 3219        3219  0500000US72151    Yabucoa Municipio, Puerto Rico
# 3220        3220  0500000US72153      Yauco Municipio, Puerto Rico
#
#       total_population  total_male  total_female  under_5_years  median_age  \
# 0                58239       28206         30033           3318        38.5
# 1               227131      110781        116350          12035        43.4
# 2                25259       13361         11898           1320        40.2
# 3                22412       12300         10112           1196        39.7
# 4                58884       29530         29354           3467        41.1
# ...                ...         ...           ...            ...         ...
# 3216             54544       26057         28487           2192        43.1
# 3217              8317        4239          4078            401        43.6
# 3218             22341       10796         11545           1002        42.0
# 3219             31047       15000         16047           1092        44.9
# 3220             34704       16548         18156           1226        45.5
#
#       over_18_years  over_65_years   white  black  native  asian  islander  \
# 0             44438           8815   43755  11470      98    647         0
# 1            178105          46805  192034  19895    1259   2175         9
# 2             19995           4801   11495  11985      77    106         1
# 3             17800           3594   17020   5003      21     46         0
# 4             45201          10584   54439    760     189    216        74
# ...             ...            ...     ...    ...     ...    ...       ...
# 3216          44604          11463   30690   2409      50      9         0
# 3217           6760           1904    2592    629       0     14         0
# 3218          17811           4188   10502   1784       0      0         0
# 3219          25533           6801    3190  16119       0     11         0
# 3220          28555           7998   24533   1282      48      0         0
#
#       other_race  more_one_race  latino  num_households_dp2  \
# 0            196           2073    1775             21856.0
# 1           4163           7596   10634             87190.0
# 2            977            618    1176              9088.0
# 3             21            301     634              7083.0
# 4           1243           1963    5612             21300.0
# ...          ...            ...     ...                 ...
# 3216        8648          12738   53313                 NaN
# 3217        4766            316    7662                 NaN
# 3218        2351           7704   22259                 NaN
# 3219       10889            838   31009                 NaN
# 3220        6243           2598   34341                 NaN
#
#       perc_hh_w_children  avg_household_size  avg_family_size  \
# 0                   34.1                2.64             3.20
# 1                   26.8                2.57             3.20
# 2                   31.0                2.45             3.15
# 3                   32.4                2.96             3.63
# 4                   32.8                2.74             3.30
# ...                  ...                 ...              ...
# 3216                 NaN                 NaN              NaN
# 3217                 NaN                 NaN              NaN
# 3218                 NaN                 NaN              NaN
# 3219                 NaN                 NaN              NaN
# 3220                 NaN                 NaN              NaN
#
#       pop_in_households  pop_in_households_child  pop_enrolled  \
# 0               57692.0                  18266.0       13755.0
# 1              224205.0                  63444.0       47081.0
# 2               22295.0                   6777.0        5648.0
# 3               20972.0                   6924.0        4223.0
# 4               58352.0                  17784.0       12696.0
# ...                 ...                      ...           ...
# 3216                NaN                      NaN           NaN
# 3217                NaN                      NaN           NaN
# 3218                NaN                      NaN           NaN
# 3219                NaN                      NaN           NaN
# 3220                NaN                      NaN           NaN
#
#       college_graduates  tot_pop_birth_native  tot_pop_birth_foreign  \
# 0               11144.0               56998.0                 1241.0
# 1               52562.0              219193.0                 7938.0
# 2                2007.0               24600.0                  659.0
# 3                1913.0               22167.0                  245.0
# 4                6061.0               56234.0                 2650.0
# ...                 ...                   ...                    ...
# 3216                NaN                   NaN                    NaN
# 3217                NaN                   NaN                    NaN
# 3218                NaN                   NaN                    NaN
# 3219                NaN                   NaN                    NaN
# 3220                NaN                   NaN                    NaN
#
#       speaks_english_only  speaks_english_less_very_well  unemployment_rate  \
# 0                 52993.0                          398.0                2.8
# 1                203884.0                         4032.0                3.7
# 2                 22207.0                          597.0                8.6
# 3                 20858.0                          114.0                9.7
# 4                 51064.0                         1859.0                6.0
# ...                   ...                            ...                ...
# 3216                  NaN                            NaN               17.6
# 3217                  NaN                            NaN               15.2
# 3218                  NaN                            NaN               18.6
# 3219                  NaN                            NaN               15.2
# 3220                  NaN                            NaN               17.4
#
#       work_from_home  median_hh_income_d  average_hh_income_d  \
# 0               1254               62660                79498
# 1               8013               64346                87709
# 2                137               36422                55066
# 3                368               54277                67396
# 4                678               52830                71849
# ...              ...                 ...                  ...
# 3216             328               21507                31473
# 3217             495               14942                21263
# 3218              17               20722                33589
# 3219               1               17267                24723
# 3220             469               16444                25206
#
#       hh_social_security  hh_foodstamps_snap  per_capita_income_d  \
# 0                   7382                2298                30968
# 1                  33929                5839                35384
# 2                   4198                2331                21325
# 3                   3346                1198                24787
# 4                   8238                2135                27309
# ...                  ...                 ...                  ...
# 3216                9794                8044                12361
# 3217                1217                1028                 8834
# 3218                3843                4632                12179
# 3219                6560                7203                10507
# 3220                6295                5805                10231
#
#       perc_fam_bellow_poverty  perc_ppl_bellow_poverty  state  county
# 0                        12.0                     13.6      1       1
# 1                         5.9                      9.2      1       3
# 2                        21.7                     26.5      1       5
# 3                        13.4                     16.9      1       7
# 4                         9.3                     13.2      1       9
# ...                       ...                      ...    ...     ...
# 3216                     38.0                     43.4     72     145
# 3217                     45.2                     53.2     72     147
# 3218                     40.9                     44.5     72     149
# 3219                     47.1                     52.6     72     151
# 3220                     43.3                     46.4     72     153
#
# [3221 rows x 41 columns]

# %%
census_data
# Out:
#       Unnamed: 0          geo_id                       census_name  \
# 0              0  0500000US01001           Autauga County, Alabama
# 1              1  0500000US01003           Baldwin County, Alabama
# 2              2  0500000US01005           Barbour County, Alabama
# 3              3  0500000US01007              Bibb County, Alabama
# 4              4  0500000US01009            Blount County, Alabama
# ...          ...             ...                               ...
# 3216        3216  0500000US72145  Vega Baja Municipio, Puerto Rico
# 3217        3217  0500000US72147    Vieques Municipio, Puerto Rico
# 3218        3218  0500000US72149   Villalba Municipio, Puerto Rico
# 3219        3219  0500000US72151    Yabucoa Municipio, Puerto Rico
# 3220        3220  0500000US72153      Yauco Municipio, Puerto Rico
#
#       total_population  total_male  total_female  under_5_years  median_age  \
# 0                58239       28206         30033           3318        38.5
# 1               227131      110781        116350          12035        43.4
# 2                25259       13361         11898           1320        40.2
# 3                22412       12300         10112           1196        39.7
# 4                58884       29530         29354           3467        41.1
# ...                ...         ...           ...            ...         ...
# 3216             54544       26057         28487           2192        43.1
# 3217              8317        4239          4078            401        43.6
# 3218             22341       10796         11545           1002        42.0
# 3219             31047       15000         16047           1092        44.9
# 3220             34704       16548         18156           1226        45.5
#
#       over_18_years  over_65_years   white  black  native  asian  islander  \
# 0             44438           8815   43755  11470      98    647         0
# 1            178105          46805  192034  19895    1259   2175         9
# 2             19995           4801   11495  11985      77    106         1
# 3             17800           3594   17020   5003      21     46         0
# 4             45201          10584   54439    760     189    216        74
# ...             ...            ...     ...    ...     ...    ...       ...
# 3216          44604          11463   30690   2409      50      9         0
# 3217           6760           1904    2592    629       0     14         0
# 3218          17811           4188   10502   1784       0      0         0
# 3219          25533           6801    3190  16119       0     11         0
# 3220          28555           7998   24533   1282      48      0         0
#
#       other_race  more_one_race  latino  num_households_dp2  \
# 0            196           2073    1775             21856.0
# 1           4163           7596   10634             87190.0
# 2            977            618    1176              9088.0
# 3             21            301     634              7083.0
# 4           1243           1963    5612             21300.0
# ...          ...            ...     ...                 ...
# 3216        8648          12738   53313                 NaN
# 3217        4766            316    7662                 NaN
# 3218        2351           7704   22259                 NaN
# 3219       10889            838   31009                 NaN
# 3220        6243           2598   34341                 NaN
#
#       perc_hh_w_children  avg_household_size  avg_family_size  \
# 0                   34.1                2.64             3.20
# 1                   26.8                2.57             3.20
# 2                   31.0                2.45             3.15
# 3                   32.4                2.96             3.63
# 4                   32.8                2.74             3.30
# ...                  ...                 ...              ...
# 3216                 NaN                 NaN              NaN
# 3217                 NaN                 NaN              NaN
# 3218                 NaN                 NaN              NaN
# 3219                 NaN                 NaN              NaN
# 3220                 NaN                 NaN              NaN
#
#       pop_in_households  pop_in_households_child  pop_enrolled  \
# 0               57692.0                  18266.0       13755.0
# 1              224205.0                  63444.0       47081.0
# 2               22295.0                   6777.0        5648.0
# 3               20972.0                   6924.0        4223.0
# 4               58352.0                  17784.0       12696.0
# ...                 ...                      ...           ...
# 3216                NaN                      NaN           NaN
# 3217                NaN                      NaN           NaN
# 3218                NaN                      NaN           NaN
# 3219                NaN                      NaN           NaN
# 3220                NaN                      NaN           NaN
#
#       college_graduates  tot_pop_birth_native  tot_pop_birth_foreign  \
# 0               11144.0               56998.0                 1241.0
# 1               52562.0              219193.0                 7938.0
# 2                2007.0               24600.0                  659.0
# 3                1913.0               22167.0                  245.0
# 4                6061.0               56234.0                 2650.0
# ...                 ...                   ...                    ...
# 3216                NaN                   NaN                    NaN
# 3217                NaN                   NaN                    NaN
# 3218                NaN                   NaN                    NaN
# 3219                NaN                   NaN                    NaN
# 3220                NaN                   NaN                    NaN
#
#       speaks_english_only  speaks_english_less_very_well  unemployment_rate  \
# 0                 52993.0                          398.0                2.8
# 1                203884.0                         4032.0                3.7
# 2                 22207.0                          597.0                8.6
# 3                 20858.0                          114.0                9.7
# 4                 51064.0                         1859.0                6.0
# ...                   ...                            ...                ...
# 3216                  NaN                            NaN               17.6
# 3217                  NaN                            NaN               15.2
# 3218                  NaN                            NaN               18.6
# 3219                  NaN                            NaN               15.2
# 3220                  NaN                            NaN               17.4
#
#       work_from_home  median_hh_income_d  average_hh_income_d  \
# 0               1254               62660                79498
# 1               8013               64346                87709
# 2                137               36422                55066
# 3                368               54277                67396
# 4                678               52830                71849
# ...              ...                 ...                  ...
# 3216             328               21507                31473
# 3217             495               14942                21263
# 3218              17               20722                33589
# 3219               1               17267                24723
# 3220             469               16444                25206
#
#       hh_social_security  hh_foodstamps_snap  per_capita_income_d  \
# 0                   7382                2298                30968
# 1                  33929                5839                35384
# 2                   4198                2331                21325
# 3                   3346                1198                24787
# 4                   8238                2135                27309
# ...                  ...                 ...                  ...
# 3216                9794                8044                12361
# 3217                1217                1028                 8834
# 3218                3843                4632                12179
# 3219                6560                7203                10507
# 3220                6295                5805                10231
#
#       perc_fam_bellow_poverty  perc_ppl_bellow_poverty  state  county
# 0                        12.0                     13.6      1       1
# 1                         5.9                      9.2      1       3
# 2                        21.7                     26.5      1       5
# 3                        13.4                     16.9      1       7
# 4                         9.3                     13.2      1       9
# ...                       ...                      ...    ...     ...
# 3216                     38.0                     43.4     72     145
# 3217                     45.2                     53.2     72     147
# 3218                     40.9                     44.5     72     149
# 3219                     47.1                     52.6     72     151
# 3220                     43.3                     46.4     72     153
#
# [3221 rows x 41 columns]

# %%
#census_data.query('census_name'== [Chicago'])
                                   
#Chicago_census_data = census_data.query('census_name == "Chicago"')

#Chicago_census_data= census_data.groupby('census_name'== ['Chicago'])

#Chicago_census_data.groupby(census_data)

#print(census_data)

#census_state_data = census_data.groupby('state' == '17')


#grouped = census_data.groupby('state')
#filtered = grouped.filter(lambda x: x['state'].iloc[0] == '17')
#filtered

census_state_data = census_data[census_data['state'] == 17]
census_state_data
#census_state_data.loc[(census_state_data['census_name']=='Cook County, Illinois')]
#here I only got it to loc by Cook County
# Out:
#      Unnamed: 0          geo_id                  census_name  \
# 596         596  0500000US17001       Adams County, Illinois
# 597         597  0500000US17003   Alexander County, Illinois
# 598         598  0500000US17005        Bond County, Illinois
# 599         599  0500000US17007       Boone County, Illinois
# 600         600  0500000US17009       Brown County, Illinois
# ..          ...             ...                          ...
# 693         693  0500000US17195   Whiteside County, Illinois
# 694         694  0500000US17197        Will County, Illinois
# 695         695  0500000US17199  Williamson County, Illinois
# 696         696  0500000US17201   Winnebago County, Illinois
# 697         697  0500000US17203    Woodford County, Illinois
#
#      total_population  total_male  total_female  under_5_years  median_age  \
# 596             65878       32414         33464           3967        41.2
# 597              5488        2652          2836            239        45.5
# 598             16804        8877          7927            681        41.5
# 599             53592       26786         26806           2902        38.8
# 600              6330        4067          2263            299        38.1
# ..                ...         ...           ...            ...         ...
# 693             55932       28065         27867           3115        43.6
# 694            696403      347369        349034          39619        38.3
# 695             67271       33700         33571           3832        41.1
# 696            285471      140109        145362          17837        39.6
# 697             38571       19271         19300           2265        40.0
#
#      over_18_years  over_65_years   white  black  native  asian  islander  \
# 596          50882          13153   60689   2615      51    420         8
# 597           4242           1233    3502   1836       4      1        22
# 598          13668           3144   15120   1184     112    165         0
# 599          40386           8596   44895   1437     160    523         0
# 600           5227            891    4876   1174      39      3         0
# ..             ...            ...     ...    ...     ...    ...       ...
# 693          43534          11529   51386    589      75    339        67
# 694         523977          91810  487812  79621    2948  39763       140
# 695          52498          12672   60606   2717     151    887         0
# 696         218063          49935  212858  37961     738   8068       101
# 697          29197           6849   37166    289      16    168         0
#
#      other_race  more_one_race  latino  num_households_dp2  \
# 596         153           1942    1146             27174.0
# 597           0            123      62              1781.0
# 598          36            187     630              6094.0
# 599        4200           2377   12223             18897.0
# 600         135            103     436              1998.0
# ..          ...            ...     ...                 ...
# 693         866           2610    6964             23194.0
# 694       43346          42773  126302            237043.0
# 695         676           2234    1858             28057.0
# 696        8582          17163   38627            115240.0
# 697         253            679     731             14675.0
#
#      perc_hh_w_children  avg_household_size  avg_family_size  \
# 596                27.0                2.38             2.99
# 597                18.0                3.00             4.34
# 598                30.3                2.43             3.06
# 599                35.4                2.82             3.31
# 600                23.5                2.24             3.03
# ..                  ...                 ...              ...
# 693                28.9                2.37             2.95
# 694                37.6                2.90             3.39
# 695                27.7                2.32             2.88
# 696                29.8                2.44             3.03
# 697                30.8                2.56             3.06
#
#      pop_in_households  pop_in_households_child  pop_enrolled  \
# 596            64574.0                  18024.0       14644.0
# 597             5344.0                   2071.0        1261.0
# 598            14825.0                   4064.0        4191.0
# 599            53259.0                  17524.0       13635.0
# 600             4469.0                   1278.0        1214.0
# ..                 ...                      ...           ...
# 693            54920.0                  15770.0       12105.0
# 694           687576.0                 238398.0      184424.0
# 695            65148.0                  17279.0       14845.0
# 696           281286.0                  82632.0       65851.0
# 697            37539.0                  11625.0       10025.0
#
#      college_graduates  tot_pop_birth_native  tot_pop_birth_foreign  \
# 596            11810.0               65003.0                  875.0
# 597              468.0                5460.0                   28.0
# 598             2534.0               16477.0                  327.0
# 599             8795.0               48625.0                 4967.0
# 600              601.0                6151.0                  179.0
# ..                 ...                   ...                    ...
# 693             7398.0               54193.0                 1739.0
# 694           162906.0              610361.0                86042.0
# 695            12764.0               65999.0                 1272.0
# 696            45227.0              259752.0                25719.0
# 697             9059.0               37903.0                  668.0
#
#      speaks_english_only  speaks_english_less_very_well  unemployment_rate  \
# 596              60491.0                          172.0                4.2
# 597               5216.0                            8.0               10.6
# 598              15647.0                          153.0                3.8
# 599              41080.0                         3171.0                8.2
# 600               5686.0                           87.0                1.5
# ..                   ...                            ...                ...
# 693              48954.0                         1248.0                4.1
# 694             521895.0                        48966.0                5.2
# 695              61088.0                          597.0                4.7
# 696             227562.0                        12520.0                7.9
# 697              35651.0                          193.0                3.5
#
#      work_from_home  median_hh_income_d  average_hh_income_d  \
# 596            1936               58587                76259
# 597              99               39871                52409
# 598             465               53654                71898
# 599            1539               74076                93405
# 600             147               59346                69410
# ..              ...                 ...                  ...
# 693             790               59812                76215
# 694           32857               95751               116288
# 695            1802               54682                73876
# 696            7717               57779                75845
# 697            1447               76486                98120
#
#      hh_social_security  hh_foodstamps_snap  per_capita_income_d  \
# 596                9363                3563                32249
# 597                 929                 313                20271
# 598                2219                 823                27335
# 599                6000                2179                34116
# 600                 597                 206                23615
# ..                  ...                 ...                  ...
# 693                8666                2998                32428
# 694               63990               21134                40493
# 695                9875                3861                31295
# 696               38826               21123                31134
# 697                5046                 974                38480
#
#      perc_fam_bellow_poverty  perc_ppl_bellow_poverty  state  county
# 596                      8.7                     11.9     17       1
# 597                     15.4                     24.5     17       3
# 598                     10.2                     15.1     17       5
# 599                      6.1                      9.3     17       7
# 600                      5.8                      9.7     17       9
# ..                       ...                      ...    ...     ...
# 693                      9.0                     12.1     17     195
# 694                      5.0                      6.8     17     197
# 695                     10.4                     13.9     17     199
# 696                     11.8                     15.9     17     201
# 697                      4.5                      6.2     17     203
#
# [102 rows x 41 columns]

# %%
counties = ['Cook County, Illinois', 'Lake County, Illinois', 'DuPage County, Illinois','Will County, Illinois','McHenry County, Illinois','Kane County,Illinois', 'Kendall County, Illinois']  # replace with your actual counties
census_counties_data = census_state_data[census_state_data['census_name'].isin(counties)]
census_counties_data
# Out:
#      Unnamed: 0          geo_id               census_name  total_population  \
# 611         611  0500000US17031     Cook County, Illinois           5265398
# 617         617  0500000US17043   DuPage County, Illinois            934094
# 642         642  0500000US17093  Kendall County, Illinois            130757
# 644         644  0500000US17097     Lake County, Illinois            714484
# 651         651  0500000US17111  McHenry County, Illinois            310749
# 694         694  0500000US17197     Will County, Illinois            696403
#
#      total_male  total_female  under_5_years  median_age  over_18_years  \
# 611     2570478       2694920         312408        37.3        4113751
# 617      461851        472243          54019        39.7         721393
# 642       64996         65761           8289        35.8          93603
# 644      358911        355573          39917        38.5         542057
# 651      155410        155339          16737        40.4         237841
# 694      347369        349034          39619        38.3         523977
#
#      over_65_years    white    black  native   asian  islander  other_race  \
# 611         774279  2740032  1211240   22867  396831      2068      523543
# 617         146886   677738    45922    2202  114491       375       37323
# 642          13534    99830    10664     334    3848         0        5906
# 644         102890   499259    48075    3887   58802       424       53828
# 651          46037   275551     4737     476    8440         5        5427
# 694          91810   487812    79621    2948   39763       140       43346
#
#      more_one_race   latino  num_households_dp2  perc_hh_w_children  \
# 611         368817  1346949           2044658.0                28.1
# 617          56043   135909            347385.0                32.5
# 642          10175    26347             43225.0                44.2
# 644          50209   159640            252731.0                35.1
# 651          16113    42981            114446.0                34.8
# 694          42773   126302            237043.0                37.6
#
#      avg_household_size  avg_family_size  pop_in_households  \
# 611                2.53             3.33          5176131.0
# 617                2.65             3.20           921130.0
# 642                3.02             3.42           130431.0
# 644                2.75             3.28           695686.0
# 651                2.70             3.12           308871.0
# 694                2.90             3.39           687576.0
#
#      pop_in_households_child  pop_enrolled  college_graduates  \
# 611                1553695.0     1276692.0          1489931.0
# 617                 292539.0      240067.0           325349.0
# 642                  48686.0       38361.0            29326.0
# 644                 233551.0      191435.0           217451.0
# 651                  99397.0       77823.0            74658.0
# 694                 238398.0      184424.0           162906.0
#
#      tot_pop_birth_native  tot_pop_birth_foreign  speaks_english_only  \
# 611             4163385.0              1102013.0            3215693.0
# 617              751394.0               182700.0             630438.0
# 642              118635.0                12122.0             100369.0
# 644              581208.0               133276.0             477010.0
# 651              283400.0                27349.0             253425.0
# 694              610361.0                86042.0             521895.0
#
#      speaks_english_less_very_well  unemployment_rate  work_from_home  \
# 611                       673502.0                7.3          287499
# 617                        77913.0                4.8           67401
# 642                         6443.0                4.3            6835
# 644                        65001.0                5.5           45081
# 651                        13138.0                5.1           17853
# 694                        48966.0                5.2           32857
#
#      median_hh_income_d  average_hh_income_d  hh_social_security  \
# 611               72121               104880              535150
# 617              100292               133288               92573
# 642              101816               115448               10122
# 644               97127               136312               68366
# 651               93801               115692               33060
# 694               95751               116288               63990
#
#      hh_foodstamps_snap  per_capita_income_d  perc_fam_bellow_poverty  \
# 611              290776                41706                      9.9
# 617               21700                50344                      4.3
# 642                3579                38343                      3.1
# 644               21215                49440                      5.2
# 651                7136                43047                      4.6
# 694               21134                40493                      5.0
#
#      perc_ppl_bellow_poverty  state  county
# 611                     13.5     17      31
# 617                      6.1     17      43
# 642                      4.4     17      93
# 644                      7.6     17      97
# 651                      6.3     17     111
# 694                      6.8     17     197

# %%
census_state_data = census_data[census_data['state'] == 17]
census_state_data
# Out:
#      Unnamed: 0          geo_id                  census_name  \
# 596         596  0500000US17001       Adams County, Illinois
# 597         597  0500000US17003   Alexander County, Illinois
# 598         598  0500000US17005        Bond County, Illinois
# 599         599  0500000US17007       Boone County, Illinois
# 600         600  0500000US17009       Brown County, Illinois
# ..          ...             ...                          ...
# 693         693  0500000US17195   Whiteside County, Illinois
# 694         694  0500000US17197        Will County, Illinois
# 695         695  0500000US17199  Williamson County, Illinois
# 696         696  0500000US17201   Winnebago County, Illinois
# 697         697  0500000US17203    Woodford County, Illinois
#
#      total_population  total_male  total_female  under_5_years  median_age  \
# 596             65878       32414         33464           3967        41.2
# 597              5488        2652          2836            239        45.5
# 598             16804        8877          7927            681        41.5
# 599             53592       26786         26806           2902        38.8
# 600              6330        4067          2263            299        38.1
# ..                ...         ...           ...            ...         ...
# 693             55932       28065         27867           3115        43.6
# 694            696403      347369        349034          39619        38.3
# 695             67271       33700         33571           3832        41.1
# 696            285471      140109        145362          17837        39.6
# 697             38571       19271         19300           2265        40.0
#
#      over_18_years  over_65_years   white  black  native  asian  islander  \
# 596          50882          13153   60689   2615      51    420         8
# 597           4242           1233    3502   1836       4      1        22
# 598          13668           3144   15120   1184     112    165         0
# 599          40386           8596   44895   1437     160    523         0
# 600           5227            891    4876   1174      39      3         0
# ..             ...            ...     ...    ...     ...    ...       ...
# 693          43534          11529   51386    589      75    339        67
# 694         523977          91810  487812  79621    2948  39763       140
# 695          52498          12672   60606   2717     151    887         0
# 696         218063          49935  212858  37961     738   8068       101
# 697          29197           6849   37166    289      16    168         0
#
#      other_race  more_one_race  latino  num_households_dp2  \
# 596         153           1942    1146             27174.0
# 597           0            123      62              1781.0
# 598          36            187     630              6094.0
# 599        4200           2377   12223             18897.0
# 600         135            103     436              1998.0
# ..          ...            ...     ...                 ...
# 693         866           2610    6964             23194.0
# 694       43346          42773  126302            237043.0
# 695         676           2234    1858             28057.0
# 696        8582          17163   38627            115240.0
# 697         253            679     731             14675.0
#
#      perc_hh_w_children  avg_household_size  avg_family_size  \
# 596                27.0                2.38             2.99
# 597                18.0                3.00             4.34
# 598                30.3                2.43             3.06
# 599                35.4                2.82             3.31
# 600                23.5                2.24             3.03
# ..                  ...                 ...              ...
# 693                28.9                2.37             2.95
# 694                37.6                2.90             3.39
# 695                27.7                2.32             2.88
# 696                29.8                2.44             3.03
# 697                30.8                2.56             3.06
#
#      pop_in_households  pop_in_households_child  pop_enrolled  \
# 596            64574.0                  18024.0       14644.0
# 597             5344.0                   2071.0        1261.0
# 598            14825.0                   4064.0        4191.0
# 599            53259.0                  17524.0       13635.0
# 600             4469.0                   1278.0        1214.0
# ..                 ...                      ...           ...
# 693            54920.0                  15770.0       12105.0
# 694           687576.0                 238398.0      184424.0
# 695            65148.0                  17279.0       14845.0
# 696           281286.0                  82632.0       65851.0
# 697            37539.0                  11625.0       10025.0
#
#      college_graduates  tot_pop_birth_native  tot_pop_birth_foreign  \
# 596            11810.0               65003.0                  875.0
# 597              468.0                5460.0                   28.0
# 598             2534.0               16477.0                  327.0
# 599             8795.0               48625.0                 4967.0
# 600              601.0                6151.0                  179.0
# ..                 ...                   ...                    ...
# 693             7398.0               54193.0                 1739.0
# 694           162906.0              610361.0                86042.0
# 695            12764.0               65999.0                 1272.0
# 696            45227.0              259752.0                25719.0
# 697             9059.0               37903.0                  668.0
#
#      speaks_english_only  speaks_english_less_very_well  unemployment_rate  \
# 596              60491.0                          172.0                4.2
# 597               5216.0                            8.0               10.6
# 598              15647.0                          153.0                3.8
# 599              41080.0                         3171.0                8.2
# 600               5686.0                           87.0                1.5
# ..                   ...                            ...                ...
# 693              48954.0                         1248.0                4.1
# 694             521895.0                        48966.0                5.2
# 695              61088.0                          597.0                4.7
# 696             227562.0                        12520.0                7.9
# 697              35651.0                          193.0                3.5
#
#      work_from_home  median_hh_income_d  average_hh_income_d  \
# 596            1936               58587                76259
# 597              99               39871                52409
# 598             465               53654                71898
# 599            1539               74076                93405
# 600             147               59346                69410
# ..              ...                 ...                  ...
# 693             790               59812                76215
# 694           32857               95751               116288
# 695            1802               54682                73876
# 696            7717               57779                75845
# 697            1447               76486                98120
#
#      hh_social_security  hh_foodstamps_snap  per_capita_income_d  \
# 596                9363                3563                32249
# 597                 929                 313                20271
# 598                2219                 823                27335
# 599                6000                2179                34116
# 600                 597                 206                23615
# ..                  ...                 ...                  ...
# 693                8666                2998                32428
# 694               63990               21134                40493
# 695                9875                3861                31295
# 696               38826               21123                31134
# 697                5046                 974                38480
#
#      perc_fam_bellow_poverty  perc_ppl_bellow_poverty  state  county
# 596                      8.7                     11.9     17       1
# 597                     15.4                     24.5     17       3
# 598                     10.2                     15.1     17       5
# 599                      6.1                      9.3     17       7
# 600                      5.8                      9.7     17       9
# ..                       ...                      ...    ...     ...
# 693                      9.0                     12.1     17     195
# 694                      5.0                      6.8     17     197
# 695                     10.4                     13.9     17     199
# 696                     11.8                     15.9     17     201
# 697                      4.5                      6.2     17     203
#
# [102 rows x 41 columns]

# %%
census_counties = gpd.read_file('../rafi-grocery/data/county shape file/cb_2018_us_county_500k.shp')
census_counties.head()
territories = ['72', '69', '66', '78','60','02','15']
updated_census_counties = census_counties.drop(census_counties[census_counties['STATEFP'].isin(territories)].index)
updated_census_counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID     NAME LSAD       ALAND  \
# 0      21      007  00516850  0500000US21007  21007  Ballard   06   639387454
# 1      21      017  00516855  0500000US21017  21017  Bourbon   06   750439351
# 2      21      031  00516862  0500000US21031  21031   Butler   06  1103571974
# 3      21      065  00516879  0500000US21065  21065   Estill   06   655509930
# 4      21      069  00516881  0500000US21069  21069  Fleming   06   902727151
#
#      AWATER                                           geometry
# 0  69473325  POLYGON ((-89.18137 37.04630, -89.17938 37.053...
# 1   4829777  POLYGON ((-84.44266 38.28324, -84.44114 38.283...
# 2  13943044  POLYGON ((-86.94486 37.07341, -86.94346 37.074...
# 3   6516335  POLYGON ((-84.12662 37.64540, -84.12483 37.646...
# 4   7182793  POLYGON ((-83.98428 38.44549, -83.98246 38.450...

# %%
census_counties.plot()
# Out:
# <Axes: >

# %%
updated_counties2 = census_counties[census_counties['STATEFP']=='17']
updated_counties2
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 11        17      091  00424247  0500000US17091  17091    Kankakee   06
# 12        17      187  01785134  0500000US17187  17187      Warren   06
# 13        17      197  01785190  0500000US17197  17197        Will   06
# 288       17      027  00424215  0500000US17027  17027     Clinton   06
# 289       17      031  01784766  0500000US17031  17031        Cook   06
# ...      ...      ...       ...             ...    ...         ...  ...
# 3029      17      143  01784920  0500000US17143  17143      Peoria   06
# 3039      17      169  01785037  0500000US17169  17169    Schuyler   06
# 3040      17      171  00424286  0500000US17171  17171       Scott   06
# 3067      17      199  01785215  0500000US17199  17199  Williamson   06
# 3226      17      065  00424234  0500000US17065  17065    Hamilton   06
#
#            ALAND      AWATER  \
# 11    1752121058    12440760
# 12    1404747944     1674135
# 13    2164927644    34548925
# 288   1227664369    75635324
# 289   2447370818  1786313044
# ...          ...         ...
# 3029  1602352656    30706564
# 3039  1132511778    10511618
# 3040   649861225     4812707
# 3067  1088263100    62602559
# 3226  1125696542     3172088
#
#                                                geometry
# 11    POLYGON ((-88.25150 41.11422, -88.24089 41.114...
# 12    POLYGON ((-90.78965 40.63685, -90.78956 40.642...
# 13    POLYGON ((-88.26127 41.72466, -88.25477 41.724...
# 288   POLYGON ((-89.70695 38.65503, -89.68784 38.655...
# 289   POLYGON ((-88.26364 42.06687, -88.25835 42.066...
# ...                                                 ...
# 3029  POLYGON ((-89.98860 40.62801, -89.98889 40.629...
# 3039  POLYGON ((-90.91288 40.14382, -90.91197 40.193...
# 3040  POLYGON ((-90.64599 39.70337, -90.64525 39.706...
# 3067  POLYGON ((-89.15264 37.68680, -89.15238 37.712...
# 3226  POLYGON ((-88.70660 37.92190, -88.70644 37.927...
#
# [102 rows x 10 columns]

# %%
updated_counties2.plot()
# Out:
# <Axes: >

# %%
updated_counties2.plot(column="white",legend=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'white'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 updated_counties2.plot(column="white",legend=True)
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/plotting.py:969, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     967 kind = kwargs.pop("kind", "geo")
#     968 if kind == "geo":
# --> 969     return plot_dataframe(data, *args, **kwargs)
#     970 if kind in self._pandas_kinds:
#     971     # Access pandas plots
#     972     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/plotting.py:730, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     728             values = values.reindex(df.index)
#     729 else:
# --> 730     values = df[column]
#     732 if pd.api.types.is_categorical_dtype(values.dtype):
#     733     if categories is not None:
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1475, in GeoDataFrame.__getitem__(self, key)
#    1469 def __getitem__(self, key):
#    1470     """
#    1471     If the result is a column containing only 'geometry', return a
#    1472     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1473     return a GeoDataFrame.
#    1474     """
# -> 1475     result = super().__getitem__(key)
#    1476     # Custom logic to avoid waiting for pandas GH51895
#    1477     # result is not geometry dtype for multi-indexes
#    1478     if (
#    1479         pd.api.types.is_scalar(key)
#    1480         and key == ""
#    (...)
#    1483         and not is_geometry_type(result)
#    1484     ):
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'white'

# %%
# plotting the isochrones
ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
updated_counties2.plot(ax=ax, alpha = 0.3, column='black')

updated_counties2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'black'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 3
#       1 # plotting the isochrones
#       2 ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
# ----> 3 updated_counties2.plot(ax=ax, alpha = 0.3, column='black')
#       5 updated_counties2
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/plotting.py:969, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     967 kind = kwargs.pop("kind", "geo")
#     968 if kind == "geo":
# --> 969     return plot_dataframe(data, *args, **kwargs)
#     970 if kind in self._pandas_kinds:
#     971     # Access pandas plots
#     972     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/plotting.py:730, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     728             values = values.reindex(df.index)
#     729 else:
# --> 730     values = df[column]
#     732 if pd.api.types.is_categorical_dtype(values.dtype):
#     733     if categories is not None:
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1475, in GeoDataFrame.__getitem__(self, key)
#    1469 def __getitem__(self, key):
#    1470     """
#    1471     If the result is a column containing only 'geometry', return a
#    1472     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1473     return a GeoDataFrame.
#    1474     """
# -> 1475     result = super().__getitem__(key)
#    1476     # Custom logic to avoid waiting for pandas GH51895
#    1477     # result is not geometry dtype for multi-indexes
#    1478     if (
#    1479         pd.api.types.is_scalar(key)
#    1480         and key == ""
#    (...)
#    1483         and not is_geometry_type(result)
#    1484     ):
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'black'

# %%
# plotting the isochrones
ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
merged_data.plot(ax=ax, alpha = 0.3, column='native')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 # plotting the isochrones
#       2 ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
# ----> 3 merged_data.plot(ax=ax, alpha = 0.3, column='native')
#
# NameError: name 'merged_data' is not defined

# %%
updated_counties2.head()

# %%
updated_counties2.replace('STATEFP'['17'== 'Illinois'])
#code worked but not in the way that I wanted it to
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 11        17      091  00424247  0500000US17091  17091    Kankakee   06
# 12        17      187  01785134  0500000US17187  17187      Warren   06
# 13        17      197  01785190  0500000US17197  17197        Will   06
# 288       17      027  00424215  0500000US17027  17027     Clinton   06
# 289       17      031  01784766  0500000US17031  17031        Cook   06
# ...      ...      ...       ...             ...    ...         ...  ...
# 3029      17      143  01784920  0500000US17143  17143      Peoria   06
# 3039      17      169  01785037  0500000US17169  17169    Schuyler   06
# 3040      17      171  00424286  0500000US17171  17171       Scott   06
# 3067      17      199  01785215  0500000US17199  17199  Williamson   06
# 3226      17      065  00424234  0500000US17065  17065    Hamilton   06
#
#            ALAND      AWATER  \
# 11    1752121058    12440760
# 12    1404747944     1674135
# 13    2164927644    34548925
# 288   1227664369    75635324
# 289   2447370818  1786313044
# ...          ...         ...
# 3029  1602352656    30706564
# 3039  1132511778    10511618
# 3040   649861225     4812707
# 3067  1088263100    62602559
# 3226  1125696542     3172088
#
#                                                geometry
# 11    POLYGON ((-88.25150 41.11422, -88.24089 41.114...
# 12    POLYGON ((-90.78965 40.63685, -90.78956 40.642...
# 13    POLYGON ((-88.26127 41.72466, -88.25477 41.724...
# 288   POLYGON ((-89.70695 38.65503, -89.68784 38.655...
# 289   POLYGON ((-88.26364 42.06687, -88.25835 42.066...
# ...                                                 ...
# 3029  POLYGON ((-89.98860 40.62801, -89.98889 40.629...
# 3039  POLYGON ((-90.91288 40.14382, -90.91197 40.193...
# 3040  POLYGON ((-90.64599 39.70337, -90.64525 39.706...
# 3067  POLYGON ((-89.15264 37.68680, -89.15238 37.712...
# 3226  POLYGON ((-88.70660 37.92190, -88.70644 37.927...
#
# [102 rows x 10 columns]

# %%
# Replace 'df' with the name of your DataFrame
updated_counties2['STATEFP'] = updated_counties2['STATEFP'].replace('17', 'Illinois')


updated_counties2['census_name'] = updated_counties2['NAME'].str.cat(updated_counties2['STATEFP'], sep=' County, ')
updated_counties2
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#        STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 11    Illinois      091  00424247  0500000US17091  17091    Kankakee   06
# 12    Illinois      187  01785134  0500000US17187  17187      Warren   06
# 13    Illinois      197  01785190  0500000US17197  17197        Will   06
# 288   Illinois      027  00424215  0500000US17027  17027     Clinton   06
# 289   Illinois      031  01784766  0500000US17031  17031        Cook   06
# ...        ...      ...       ...             ...    ...         ...  ...
# 3029  Illinois      143  01784920  0500000US17143  17143      Peoria   06
# 3039  Illinois      169  01785037  0500000US17169  17169    Schuyler   06
# 3040  Illinois      171  00424286  0500000US17171  17171       Scott   06
# 3067  Illinois      199  01785215  0500000US17199  17199  Williamson   06
# 3226  Illinois      065  00424234  0500000US17065  17065    Hamilton   06
#
#            ALAND      AWATER  \
# 11    1752121058    12440760
# 12    1404747944     1674135
# 13    2164927644    34548925
# 288   1227664369    75635324
# 289   2447370818  1786313044
# ...          ...         ...
# 3029  1602352656    30706564
# 3039  1132511778    10511618
# 3040   649861225     4812707
# 3067  1088263100    62602559
# 3226  1125696542     3172088
#
#                                                geometry  \
# 11    POLYGON ((-88.25150 41.11422, -88.24089 41.114...
# 12    POLYGON ((-90.78965 40.63685, -90.78956 40.642...
# 13    POLYGON ((-88.26127 41.72466, -88.25477 41.724...
# 288   POLYGON ((-89.70695 38.65503, -89.68784 38.655...
# 289   POLYGON ((-88.26364 42.06687, -88.25835 42.066...
# ...                                                 ...
# 3029  POLYGON ((-89.98860 40.62801, -89.98889 40.629...
# 3039  POLYGON ((-90.91288 40.14382, -90.91197 40.193...
# 3040  POLYGON ((-90.64599 39.70337, -90.64525 39.706...
# 3067  POLYGON ((-89.15264 37.68680, -89.15238 37.712...
# 3226  POLYGON ((-88.70660 37.92190, -88.70644 37.927...
#
#                       census_name
# 11      Kankakee County, Illinois
# 12        Warren County, Illinois
# 13          Will County, Illinois
# 288      Clinton County, Illinois
# 289         Cook County, Illinois
# ...                           ...
# 3029      Peoria County, Illinois
# 3039    Schuyler County, Illinois
# 3040       Scott County, Illinois
# 3067  Williamson County, Illinois
# 3226    Hamilton County, Illinois
#
# [102 rows x 11 columns]

# %%
counties2 = ['Cook County, Illinois', 'Lake County, Illinois', 'DuPage County, Illinois','Will County, Illinois','McHenry County, Illinois','Kane County,Illinois', 'Kendall County, Illinois']  
combined_census_data = updated_counties2[census_state_data['census_name'].isin(counties)]
combined_census_data
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1475: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[57], line 2
#       1 counties = ['Cook County, Illinois', 'Lake County, Illinois', 'DuPage County, Illinois','Will County, Illinois','McHenry County, Illinois','Kane County,Illinois', 'Kendall County, Illinois']
# ----> 2 combined_census_data = updated_counties2[census_state_data['census_name'].isin(counties)]
#       3 combined_census_data
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1475, in GeoDataFrame.__getitem__(self, key)
#    1469 def __getitem__(self, key):
#    1470     """
#    1471     If the result is a column containing only 'geometry', return a
#    1472     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1473     return a GeoDataFrame.
#    1474     """
# -> 1475     result = super().__getitem__(key)
#    1476     # Custom logic to avoid waiting for pandas GH51895
#    1477     # result is not geometry dtype for multi-indexes
#    1478     if (
#    1479         pd.api.types.is_scalar(key)
#    1480         and key == ""
#    (...)
#    1483         and not is_geometry_type(result)
#    1484     ):
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:3805, in DataFrame._getitem_bool_array(self, key)
#    3799     raise ValueError(
#    3800         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3801     )
#    3803 # check_bool_indexer will throw exception if Series key cannot
#    3804 # be reindexed to match DataFrame rows
# -> 3805 key = check_bool_indexer(self.index, key)
#    3807 if key.all():
#    3808     return self.copy(deep=None)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexing.py:2506, in check_bool_indexer(index, key)
#    2504 indexer = result.index.get_indexer_for(index)
#    2505 if -1 in indexer:
# -> 2506     raise IndexingError(
#    2507         "Unalignable boolean Series provided as "
#    2508         "indexer (index of the boolean Series and of "
#    2509         "the indexed object do not match)."
#    2510     )
#    2512 result = result.take(indexer)
#    2514 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
combined_census = pd.merge(combined_census_data,2,how = "left", on = ["STATE"])
censusboundaries_hhi.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 combined_census = pd.merge(combined_census_data,2,how = "left", on = ["STATE"])
#       2 censusboundaries_hhi.head()
#
# NameError: name 'combined_census_data' is not defined

# %%
census_counties_data
# Out:
#      Unnamed: 0          geo_id               census_name  total_population  \
# 611         611  0500000US17031     Cook County, Illinois           5265398
# 617         617  0500000US17043   DuPage County, Illinois            934094
# 642         642  0500000US17093  Kendall County, Illinois            130757
# 644         644  0500000US17097     Lake County, Illinois            714484
# 651         651  0500000US17111  McHenry County, Illinois            310749
# 694         694  0500000US17197     Will County, Illinois            696403
#
#      total_male  total_female  under_5_years  median_age  over_18_years  \
# 611     2570478       2694920         312408        37.3        4113751
# 617      461851        472243          54019        39.7         721393
# 642       64996         65761           8289        35.8          93603
# 644      358911        355573          39917        38.5         542057
# 651      155410        155339          16737        40.4         237841
# 694      347369        349034          39619        38.3         523977
#
#      over_65_years    white    black  native   asian  islander  other_race  \
# 611         774279  2740032  1211240   22867  396831      2068      523543
# 617         146886   677738    45922    2202  114491       375       37323
# 642          13534    99830    10664     334    3848         0        5906
# 644         102890   499259    48075    3887   58802       424       53828
# 651          46037   275551     4737     476    8440         5        5427
# 694          91810   487812    79621    2948   39763       140       43346
#
#      more_one_race   latino  num_households_dp2  perc_hh_w_children  \
# 611         368817  1346949           2044658.0                28.1
# 617          56043   135909            347385.0                32.5
# 642          10175    26347             43225.0                44.2
# 644          50209   159640            252731.0                35.1
# 651          16113    42981            114446.0                34.8
# 694          42773   126302            237043.0                37.6
#
#      avg_household_size  avg_family_size  pop_in_households  \
# 611                2.53             3.33          5176131.0
# 617                2.65             3.20           921130.0
# 642                3.02             3.42           130431.0
# 644                2.75             3.28           695686.0
# 651                2.70             3.12           308871.0
# 694                2.90             3.39           687576.0
#
#      pop_in_households_child  pop_enrolled  college_graduates  \
# 611                1553695.0     1276692.0          1489931.0
# 617                 292539.0      240067.0           325349.0
# 642                  48686.0       38361.0            29326.0
# 644                 233551.0      191435.0           217451.0
# 651                  99397.0       77823.0            74658.0
# 694                 238398.0      184424.0           162906.0
#
#      tot_pop_birth_native  tot_pop_birth_foreign  speaks_english_only  \
# 611             4163385.0              1102013.0            3215693.0
# 617              751394.0               182700.0             630438.0
# 642              118635.0                12122.0             100369.0
# 644              581208.0               133276.0             477010.0
# 651              283400.0                27349.0             253425.0
# 694              610361.0                86042.0             521895.0
#
#      speaks_english_less_very_well  unemployment_rate  work_from_home  \
# 611                       673502.0                7.3          287499
# 617                        77913.0                4.8           67401
# 642                         6443.0                4.3            6835
# 644                        65001.0                5.5           45081
# 651                        13138.0                5.1           17853
# 694                        48966.0                5.2           32857
#
#      median_hh_income_d  average_hh_income_d  hh_social_security  \
# 611               72121               104880              535150
# 617              100292               133288               92573
# 642              101816               115448               10122
# 644               97127               136312               68366
# 651               93801               115692               33060
# 694               95751               116288               63990
#
#      hh_foodstamps_snap  per_capita_income_d  perc_fam_bellow_poverty  \
# 611              290776                41706                      9.9
# 617               21700                50344                      4.3
# 642                3579                38343                      3.1
# 644               21215                49440                      5.2
# 651                7136                43047                      4.6
# 694               21134                40493                      5.0
#
#      perc_ppl_bellow_poverty  state  county
# 611                     13.5     17      31
# 617                      6.1     17      43
# 642                      4.4     17      93
# 644                      7.6     17      97
# 651                      6.3     17     111
# 694                      6.8     17     197

# %%
merged_data = pd.merge(updated_counties2,census_counties_data,how = "left", on = ["census_name"])
merged_data
# Out:
#       STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 0    Illinois      091  00424247  0500000US17091  17091    Kankakee   06
# 1    Illinois      187  01785134  0500000US17187  17187      Warren   06
# 2    Illinois      197  01785190  0500000US17197  17197        Will   06
# 3    Illinois      027  00424215  0500000US17027  17027     Clinton   06
# 4    Illinois      031  01784766  0500000US17031  17031        Cook   06
# ..        ...      ...       ...             ...    ...         ...  ...
# 97   Illinois      143  01784920  0500000US17143  17143      Peoria   06
# 98   Illinois      169  01785037  0500000US17169  17169    Schuyler   06
# 99   Illinois      171  00424286  0500000US17171  17171       Scott   06
# 100  Illinois      199  01785215  0500000US17199  17199  Williamson   06
# 101  Illinois      065  00424234  0500000US17065  17065    Hamilton   06
#
#           ALAND      AWATER  \
# 0    1752121058    12440760
# 1    1404747944     1674135
# 2    2164927644    34548925
# 3    1227664369    75635324
# 4    2447370818  1786313044
# ..          ...         ...
# 97   1602352656    30706564
# 98   1132511778    10511618
# 99    649861225     4812707
# 100  1088263100    62602559
# 101  1125696542     3172088
#
#                                               geometry  \
# 0    POLYGON ((-88.25150 41.11422, -88.24089 41.114...
# 1    POLYGON ((-90.78965 40.63685, -90.78956 40.642...
# 2    POLYGON ((-88.26127 41.72466, -88.25477 41.724...
# 3    POLYGON ((-89.70695 38.65503, -89.68784 38.655...
# 4    POLYGON ((-88.26364 42.06687, -88.25835 42.066...
# ..                                                 ...
# 97   POLYGON ((-89.98860 40.62801, -89.98889 40.629...
# 98   POLYGON ((-90.91288 40.14382, -90.91197 40.193...
# 99   POLYGON ((-90.64599 39.70337, -90.64525 39.706...
# 100  POLYGON ((-89.15264 37.68680, -89.15238 37.712...
# 101  POLYGON ((-88.70660 37.92190, -88.70644 37.927...
#
#                      census_name  Unnamed: 0          geo_id  \
# 0      Kankakee County, Illinois         NaN             NaN
# 1        Warren County, Illinois         NaN             NaN
# 2          Will County, Illinois       694.0  0500000US17197
# 3       Clinton County, Illinois         NaN             NaN
# 4          Cook County, Illinois       611.0  0500000US17031
# ..                           ...         ...             ...
# 97       Peoria County, Illinois         NaN             NaN
# 98     Schuyler County, Illinois         NaN             NaN
# 99        Scott County, Illinois         NaN             NaN
# 100  Williamson County, Illinois         NaN             NaN
# 101    Hamilton County, Illinois         NaN             NaN
#
#      total_population  total_male  total_female  under_5_years  median_age  \
# 0                 NaN         NaN           NaN            NaN         NaN
# 1                 NaN         NaN           NaN            NaN         NaN
# 2            696403.0    347369.0      349034.0        39619.0        38.3
# 3                 NaN         NaN           NaN            NaN         NaN
# 4           5265398.0   2570478.0     2694920.0       312408.0        37.3
# ..                ...         ...           ...            ...         ...
# 97                NaN         NaN           NaN            NaN         NaN
# 98                NaN         NaN           NaN            NaN         NaN
# 99                NaN         NaN           NaN            NaN         NaN
# 100               NaN         NaN           NaN            NaN         NaN
# 101               NaN         NaN           NaN            NaN         NaN
#
#      over_18_years  over_65_years      white      black   native     asian  \
# 0              NaN            NaN        NaN        NaN      NaN       NaN
# 1              NaN            NaN        NaN        NaN      NaN       NaN
# 2         523977.0        91810.0   487812.0    79621.0   2948.0   39763.0
# 3              NaN            NaN        NaN        NaN      NaN       NaN
# 4        4113751.0       774279.0  2740032.0  1211240.0  22867.0  396831.0
# ..             ...            ...        ...        ...      ...       ...
# 97             NaN            NaN        NaN        NaN      NaN       NaN
# 98             NaN            NaN        NaN        NaN      NaN       NaN
# 99             NaN            NaN        NaN        NaN      NaN       NaN
# 100            NaN            NaN        NaN        NaN      NaN       NaN
# 101            NaN            NaN        NaN        NaN      NaN       NaN
#
#      islander  other_race  more_one_race     latino  num_households_dp2  \
# 0         NaN         NaN            NaN        NaN                 NaN
# 1         NaN         NaN            NaN        NaN                 NaN
# 2       140.0     43346.0        42773.0   126302.0            237043.0
# 3         NaN         NaN            NaN        NaN                 NaN
# 4      2068.0    523543.0       368817.0  1346949.0           2044658.0
# ..        ...         ...            ...        ...                 ...
# 97        NaN         NaN            NaN        NaN                 NaN
# 98        NaN         NaN            NaN        NaN                 NaN
# 99        NaN         NaN            NaN        NaN                 NaN
# 100       NaN         NaN            NaN        NaN                 NaN
# 101       NaN         NaN            NaN        NaN                 NaN
#
#      perc_hh_w_children  avg_household_size  avg_family_size  \
# 0                   NaN                 NaN              NaN
# 1                   NaN                 NaN              NaN
# 2                  37.6                2.90             3.39
# 3                   NaN                 NaN              NaN
# 4                  28.1                2.53             3.33
# ..                  ...                 ...              ...
# 97                  NaN                 NaN              NaN
# 98                  NaN                 NaN              NaN
# 99                  NaN                 NaN              NaN
# 100                 NaN                 NaN              NaN
# 101                 NaN                 NaN              NaN
#
#      pop_in_households  pop_in_households_child  pop_enrolled  \
# 0                  NaN                      NaN           NaN
# 1                  NaN                      NaN           NaN
# 2             687576.0                 238398.0      184424.0
# 3                  NaN                      NaN           NaN
# 4            5176131.0                1553695.0     1276692.0
# ..                 ...                      ...           ...
# 97                 NaN                      NaN           NaN
# 98                 NaN                      NaN           NaN
# 99                 NaN                      NaN           NaN
# 100                NaN                      NaN           NaN
# 101                NaN                      NaN           NaN
#
#      college_graduates  tot_pop_birth_native  tot_pop_birth_foreign  \
# 0                  NaN                   NaN                    NaN
# 1                  NaN                   NaN                    NaN
# 2             162906.0              610361.0                86042.0
# 3                  NaN                   NaN                    NaN
# 4            1489931.0             4163385.0              1102013.0
# ..                 ...                   ...                    ...
# 97                 NaN                   NaN                    NaN
# 98                 NaN                   NaN                    NaN
# 99                 NaN                   NaN                    NaN
# 100                NaN                   NaN                    NaN
# 101                NaN                   NaN                    NaN
#
#      speaks_english_only  speaks_english_less_very_well  unemployment_rate  \
# 0                    NaN                            NaN                NaN
# 1                    NaN                            NaN                NaN
# 2               521895.0                        48966.0                5.2
# 3                    NaN                            NaN                NaN
# 4              3215693.0                       673502.0                7.3
# ..                   ...                            ...                ...
# 97                   NaN                            NaN                NaN
# 98                   NaN                            NaN                NaN
# 99                   NaN                            NaN                NaN
# 100                  NaN                            NaN                NaN
# 101                  NaN                            NaN                NaN
#
#      work_from_home  median_hh_income_d  average_hh_income_d  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2           32857.0             95751.0             116288.0
# 3               NaN                 NaN                  NaN
# 4          287499.0             72121.0             104880.0
# ..              ...                 ...                  ...
# 97              NaN                 NaN                  NaN
# 98              NaN                 NaN                  NaN
# 99              NaN                 NaN                  NaN
# 100             NaN                 NaN                  NaN
# 101             NaN                 NaN                  NaN
#
#      hh_social_security  hh_foodstamps_snap  per_capita_income_d  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2               63990.0             21134.0              40493.0
# 3                   NaN                 NaN                  NaN
# 4              535150.0            290776.0              41706.0
# ..                  ...                 ...                  ...
# 97                  NaN                 NaN                  NaN
# 98                  NaN                 NaN                  NaN
# 99                  NaN                 NaN                  NaN
# 100                 NaN                 NaN                  NaN
# 101                 NaN                 NaN                  NaN
#
#      perc_fam_bellow_poverty  perc_ppl_bellow_poverty  state  county
# 0                        NaN                      NaN    NaN     NaN
# 1                        NaN                      NaN    NaN     NaN
# 2                        5.0                      6.8   17.0   197.0
# 3                        NaN                      NaN    NaN     NaN
# 4                        9.9                     13.5   17.0    31.0
# ..                       ...                      ...    ...     ...
# 97                       NaN                      NaN    NaN     NaN
# 98                       NaN                      NaN    NaN     NaN
# 99                       NaN                      NaN    NaN     NaN
# 100                      NaN                      NaN    NaN     NaN
# 101                      NaN                      NaN    NaN     NaN
#
# [102 rows x 51 columns]

# %%
counties = ['Cook County, Illinois', 'Lake County, Illinois', 'DuPage County, Illinois','Will County, Illinois','McHenry County, Illinois','Kane County,Illinois', 'Kendall County, Illinois']  # replace with your actual counties
census_counties_data = census_state_data[census_state_data['census_name'].isin(counties)]
census_counties_data
# Out:
#      Unnamed: 0          geo_id               census_name  total_population  \
# 611         611  0500000US17031     Cook County, Illinois           5265398
# 617         617  0500000US17043   DuPage County, Illinois            934094
# 642         642  0500000US17093  Kendall County, Illinois            130757
# 644         644  0500000US17097     Lake County, Illinois            714484
# 651         651  0500000US17111  McHenry County, Illinois            310749
# 694         694  0500000US17197     Will County, Illinois            696403
#
#      total_male  total_female  under_5_years  median_age  over_18_years  \
# 611     2570478       2694920         312408        37.3        4113751
# 617      461851        472243          54019        39.7         721393
# 642       64996         65761           8289        35.8          93603
# 644      358911        355573          39917        38.5         542057
# 651      155410        155339          16737        40.4         237841
# 694      347369        349034          39619        38.3         523977
#
#      over_65_years    white    black  native   asian  islander  other_race  \
# 611         774279  2740032  1211240   22867  396831      2068      523543
# 617         146886   677738    45922    2202  114491       375       37323
# 642          13534    99830    10664     334    3848         0        5906
# 644         102890   499259    48075    3887   58802       424       53828
# 651          46037   275551     4737     476    8440         5        5427
# 694          91810   487812    79621    2948   39763       140       43346
#
#      more_one_race   latino  num_households_dp2  perc_hh_w_children  \
# 611         368817  1346949           2044658.0                28.1
# 617          56043   135909            347385.0                32.5
# 642          10175    26347             43225.0                44.2
# 644          50209   159640            252731.0                35.1
# 651          16113    42981            114446.0                34.8
# 694          42773   126302            237043.0                37.6
#
#      avg_household_size  avg_family_size  pop_in_households  \
# 611                2.53             3.33          5176131.0
# 617                2.65             3.20           921130.0
# 642                3.02             3.42           130431.0
# 644                2.75             3.28           695686.0
# 651                2.70             3.12           308871.0
# 694                2.90             3.39           687576.0
#
#      pop_in_households_child  pop_enrolled  college_graduates  \
# 611                1553695.0     1276692.0          1489931.0
# 617                 292539.0      240067.0           325349.0
# 642                  48686.0       38361.0            29326.0
# 644                 233551.0      191435.0           217451.0
# 651                  99397.0       77823.0            74658.0
# 694                 238398.0      184424.0           162906.0
#
#      tot_pop_birth_native  tot_pop_birth_foreign  speaks_english_only  \
# 611             4163385.0              1102013.0            3215693.0
# 617              751394.0               182700.0             630438.0
# 642              118635.0                12122.0             100369.0
# 644              581208.0               133276.0             477010.0
# 651              283400.0                27349.0             253425.0
# 694              610361.0                86042.0             521895.0
#
#      speaks_english_less_very_well  unemployment_rate  work_from_home  \
# 611                       673502.0                7.3          287499
# 617                        77913.0                4.8           67401
# 642                         6443.0                4.3            6835
# 644                        65001.0                5.5           45081
# 651                        13138.0                5.1           17853
# 694                        48966.0                5.2           32857
#
#      median_hh_income_d  average_hh_income_d  hh_social_security  \
# 611               72121               104880              535150
# 617              100292               133288               92573
# 642              101816               115448               10122
# 644               97127               136312               68366
# 651               93801               115692               33060
# 694               95751               116288               63990
#
#      hh_foodstamps_snap  per_capita_income_d  perc_fam_bellow_poverty  \
# 611              290776                41706                      9.9
# 617               21700                50344                      4.3
# 642                3579                38343                      3.1
# 644               21215                49440                      5.2
# 651                7136                43047                      4.6
# 694               21134                40493                      5.0
#
#      perc_ppl_bellow_poverty  state  county
# 611                     13.5     17      31
# 617                      6.1     17      43
# 642                      4.4     17      93
# 644                      7.6     17      97
# 651                      6.3     17     111
# 694                      6.8     17     197

# %%
# plotting the isochrones
ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
merged_data.plot(ax=ax, alpha = 0.3, column='black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 # plotting the isochrones
#       2 ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
# ----> 3 merged_data.plot(ax=ax, alpha = 0.3, column='black')
#
# NameError: name 'merged_data' is not defined

# %%
# plotting the isochrones
ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
updated_counties2.plot(ax=ax, alpha = 0.3, column='black')
updated_counties2.plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'black'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 # plotting the isochrones
#       2 ax = updated_counties2.plot(figsize=(10, 10), color='white', linestyle=':', edgecolor='black')
# ----> 3 updated_counties2.plot(ax=ax, alpha = 0.3, column='black')
#       4 updated_counties2.plot
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/plotting.py:969, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     967 kind = kwargs.pop("kind", "geo")
#     968 if kind == "geo":
# --> 969     return plot_dataframe(data, *args, **kwargs)
#     970 if kind in self._pandas_kinds:
#     971     # Access pandas plots
#     972     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/plotting.py:730, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     728             values = values.reindex(df.index)
#     729 else:
# --> 730     values = df[column]
#     732 if pd.api.types.is_categorical_dtype(values.dtype):
#     733     if categories is not None:
#
# File /opt/tljh/user/lib/python3.9/site-packages/geopandas/geodataframe.py:1475, in GeoDataFrame.__getitem__(self, key)
#    1469 def __getitem__(self, key):
#    1470     """
#    1471     If the result is a column containing only 'geometry', return a
#    1472     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1473     return a GeoDataFrame.
#    1474     """
# -> 1475     result = super().__getitem__(key)
#    1476     # Custom logic to avoid waiting for pandas GH51895
#    1477     # result is not geometry dtype for multi-indexes
#    1478     if (
#    1479         pd.api.types.is_scalar(key)
#    1480         and key == ""
#    (...)
#    1483         and not is_geometry_type(result)
#    1484     ):
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'black'
