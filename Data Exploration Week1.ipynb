# %% [markdown]
# ## Data Exploration - Rafi Project

# %% [markdown]
# ### Start date : June 27th, 2023 ( Research Question 1)
#
# Author: Kenthia
#
# 1.For the initial exploratory data analysis:
# - How many parent companies exist in the dataset?
# - How many grocery chains do they own?
# - How do these numbers change per year?

# %%
#importing needed packages 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading in the data 

data = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
data.head()
# Out:
#    Unnamed: 0               COMPANY   ADDRESS LINE 1         CITY STATE  \
# 0         116                GOMART    55 POSTAL PLZ   MORGANTOWN    WV
# 1         120              7-ELEVEN    485 E MAIN ST    EL CENTRO    CA
# 2         247         EL SOL MARKET    110 W MAIN ST  WESTMORLAND    CA
# 3         349  COOL SPRINGS GROCERY  241 WILDWOOD ST   MORGANTOWN    WV
# 4         470              CIRCLE K    123 E MAIN ST  WESTMORLAND    CA
#
#    ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 0    26508  7005.0         61.0        304       2  ...               7
# 1    92243  2619.0         25.0        760       2  ...               7
# 2    92281     NaN         25.0        760       2  ...               3
# 3    26505  3141.0         61.0        304       2  ...               7
# 4    92281     NaN         25.0        760       2  ...               3
#
#   CENSUS TRACT  CENSUS BLOCK   LATITUDE   LONGITUDE MATCH CODE  CBSA CODE  \
# ...

# %%
#get all columns to show 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

data.head()
# Out:
#    Unnamed: 0               COMPANY   ADDRESS LINE 1         CITY STATE  \
# 0         116                GOMART    55 POSTAL PLZ   MORGANTOWN    WV
# 1         120              7-ELEVEN    485 E MAIN ST    EL CENTRO    CA
# 2         247         EL SOL MARKET    110 W MAIN ST  WESTMORLAND    CA
# 3         349  COOL SPRINGS GROCERY  241 WILDWOOD ST   MORGANTOWN    WV
# 4         470              CIRCLE K    123 E MAIN ST  WESTMORLAND    CA
#
#    ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 0    26508  7005.0         61.0        304       2
# 1    92243  2619.0         25.0        760       2
# 2    92281     NaN         25.0        760       2
# 3    26505  3141.0         61.0        304       2
# 4    92281     NaN         25.0        760       2
#
#   LOCATION EMPLOYEE SIZE CODE LOCATION SALES VOLUME CODE  PRIMARY SIC CODE  \
# 0                           C                          C            541103
# ...

# %%
#checking the number of parent companies
#PARENT NUMBER identifies corporate parent of the business
data["PARENT NUMBER"].value_counts()
# Out:
# PARENT NUMBER
# 5863311.0      11940
# 450720289.0     6819
# 5889993.0       4398
# 7521503.0       3574
# 441412723.0     2499
# 5995907.0       2493
# 200026573.0     2217
# 238136725.0     2105
# 714232249.0     1760
# 433922353.0     1755
# 4554150.0       1375
# 723360636.0     1366
# 1490291.0       1319
# 304848351.0      983
# 434705059.0      970
# 885216069.0      899
# 3573128.0        847
# 147006928.0      791
# 153215363.0      700
# 2984524.0        638
# 5644232.0        612
# 6829915.0        592
# 886012012.0      570
# 305504573.0      551
# 979589546.0      454
# 744686962.0      444
# 891525875.0      442
# 5162565.0        439
# 526940036.0      426
# 843266719.0      405
# 516134160.0      387
# 8790206.0        386
# 402336586.0      383
# 7539513.0        383
# 425105750.0      378
# 9108317.0        370
# 436443592.0      320
# 592699896.0      312
# 425128431.0      293
# 464706795.0      292
# 769874507.0      288
# 424528446.0      286
# ...

# %% [markdown]
# **Above, we can see that all parent companies and not just the ones that own grocery stores are present.**

# %%
#checking the number of grocery stores 
#GROCERY_SIC = "5411"
data["PRIMARY SIC CODE"].value_counts()
# Out:
# PRIMARY SIC CODE
# 541103    79147
# 541105    75684
# 554112    44251
# 541110     3728
# 541108      206
# 541107      108
# 554110       75
# 554111       63
# 354118       48
# 354112       41
# 154110       37
# 354110       35
# 354111       26
# 354113       20
# 354117       17
# 541106       10
# 354115        6
# 354116        1
# Name: count, dtype: int64

# %% [markdown]
# **Above we can see that all strings containing "5411" (not just at the beginning) were included.This means we need to filter out to get grocery stores only since anything with the "5411" code does not necessarily mean it is a grocery as the dataset contains all businesses across the US**

# %% [markdown]
# ### Sooo...Let's pull out what we need

# %%
#Checking to see what states we have represented 
states = data.groupby("STATE").count()['CITY']
states
# Out:
# STATE
# AK      406
# AL     3004
# AR     1836
# AZ     3393
# CA    25896
# CO     3931
# CT     2508
# DC      560
# DE      591
# FL    13099
# FM        7
# GA     6447
# GU       90
# HI      897
# IA     2415
# ID     1014
# IL     6252
# IN     3422
# KS     1686
# KY     2782
# LA     3061
# MA     5183
# MD     3773
# ME     1220
# MH        1
# MI     5196
# MN     3431
# MO     3707
# MP       35
# MS     1920
# MT      741
# NC     7088
# ND      610
# NE     1344
# NH     1066
# NJ     5143
# NM     1125
# NV     1779
# NY    13229
# OH     6408
# OK     2363
# OR     3257
# PA     7871
# PR      869
# RI      711
# SC     3466
# SD      693
# TN     4651
# TX    15728
# UT     1737
# VA     5431
# VI       23
# VT      841
# WA     4629
# WI     3177
# WV     1383
# WY      377
# Name: CITY, dtype: int64

# %%
data.shape
# Out:
# (203503, 54)

# %%
#Taking out US territories from the dataset ( leaving DC )
stores_2022 = pd.read_csv('/srv/data/my_shared_data_folder/rafi/2022_Business_Academic_QCQ_grocery.csv')
stores_2022.drop(['Unnamed: 0'],inplace=True,axis=1)
territories = ['PR', 'FM', 'MP', 'GU', 'VI', 'MH']
stores_2022 = stores_2022.drop(stores_2022[stores_2022['STATE'].isin(territories)].index)
stores_2022.groupby("STATE").count().shape
# Out:
# (51, 52)

# %%
stores_2022.shape
# Out:
# (202478, 53)

# %%
#Filter Grocery stores by SIC (starting with 5411)
grocery_sic = stores_2022.loc[stores_2022[['PRIMARY SIC CODE', 'SIC CODE', 'SIC CODE 1', 'SIC CODE 2', 'SIC CODE 3', 'SIC CODE 4']].astype(str).apply(lambda x: x.str.startswith('5411')).any(axis=1)]
grocery_sic.head()
# Out:
#                 COMPANY   ADDRESS LINE 1         CITY STATE  ZIPCODE    ZIP4  \
# 0                GOMART    55 POSTAL PLZ   MORGANTOWN    WV    26508  7005.0
# 1              7-ELEVEN    485 E MAIN ST    EL CENTRO    CA    92243  2619.0
# 2         EL SOL MARKET    110 W MAIN ST  WESTMORLAND    CA    92281     NaN
# 3  COOL SPRINGS GROCERY  241 WILDWOOD ST   MORGANTOWN    WV    26505  3141.0
# 4              CIRCLE K    123 E MAIN ST  WESTMORLAND    CA    92281     NaN
#
#    COUNTY CODE  AREA CODE  IDCODE LOCATION EMPLOYEE SIZE CODE  \
# 0         61.0        304       2                           C
# 1         25.0        760       2                           B
# 2         25.0        760       2                           B
# 3         61.0        304       2                           A
# 4         25.0        760       2                           B
#
#   LOCATION SALES VOLUME CODE  PRIMARY SIC CODE   SIC6_DESCRIPTIONS  \
# ...

# %% [markdown]
# ### Start date : June 28th, 2023 ( Research Question 3)
#
# Author : Kenthia
#
# 3. Can market consolidation be estimated using estimated sales data and a measure of market concentration like the HerfindahlHirschman Index (HHI)?

# %%
#Find top ten parent companies
grocery_t10_22 = grocery_sic.groupby('PARENT NUMBER', dropna=False).size().reset_index(name='COUNT')
grocery_t10_22.sort_values('COUNT', ascending=False, inplace=True)
# Create other row
other_row = grocery_t10_22.iloc[10:]
other_column = other_row['COUNT'].sum()
# Remove other rows
grocery_t10_22 = grocery_t10_22.iloc[:10]
grocery_t10_22.loc[len(grocery_t10_22)] = ["Other", other_column]
grocery_t10_22['PARENT NUMBER'] = grocery_t10_22['PARENT NUMBER'].astype(str)
grocery_t10_22['Percent'] = grocery_t10_22['COUNT'] / len(grocery_sic) * 100
grocery_t10_22

#Percent tells us MarketShare (basically how much space it takes up in the grocery industry)
#Count tells us how many grocery stores are under a specific parent company/ number 
#where "NAN" means there's no data available and "Other" is everything from 11 onwards
# Out:
#      PARENT NUMBER  COUNT    Percent
# 1067           nan  77818  49.287773
# 78       5863311.0  11939   7.561833
# 585    450720289.0   6814   4.315799
# 81       5889993.0   4397   2.784938
# 92       7521503.0   3574   2.263673
# 574    441412723.0   2499   1.582798
# 84       5995907.0   2493   1.578997
# 263    200026573.0   2217   1.404187
# 281    238136725.0   2105   1.333249
# 843    714232249.0   1760   1.114735
# 10           Other  42269  26.772018

# %% [markdown]
# ## Visualizing the Top 10 Parent Companies

# %%
#Top 10 Parent (Country)
plt.bar(grocery_t10_22['PARENT NUMBER'], grocery_t10_22['Percent'])
plt.xlabel('Parent Number')
plt.ylabel('Percent')
plt.title('Top 10 Parent Numbers (Countrywide)')
plt.xticks(rotation=90)
plt.show()

# %%
#top 10 parent companies in the country 
# 1) 5863311.0 = parent company = Seven & I holdings 
# 2) 450720289.0 = parent company(s) = Alimentation Couche-Tard, Convenience Retail Asia
# 3) 5889993.0 = parent company = Walmart 
# 4) 7521503.0 = parent company = Kroger 
#5) 441412723.0 = parent company(s)= Rutters Holding Inc, CHR Corporation 
#6) 5995907.0 = parent company = Albertson, American stores 3
#7) 200026573.0 = parent company = Albrecht Discounts(aldi)
#8) not showing data = Ahold Delhaize
#9) 714232249.0 = parentt company = Clark Enterprises Inc
#10) 433922353.0 = parent compnay = Murphy Oil Corporation USA

# %%
# Every single grocery store included in this dataframe (not just top 10 )
grocery_22 = grocery_sic.groupby('PARENT NUMBER', dropna=False).size().reset_index(name='COUNT')
grocery_22.sort_values('COUNT', ascending=False, inplace=True)

grocery_22['PARENT NUMBER'] = grocery_22['PARENT NUMBER'].astype(str)
grocery_22['Percent'] = grocery_22['COUNT'] / len(grocery_sic) * 100
grocery_22 = grocery_22.reset_index(drop=True)
grocery_22
# Out:
#      PARENT NUMBER  COUNT    Percent
# 0              nan  77818  49.287773
# 1        5863311.0  11939   7.561833
# 2      450720289.0   6814   4.315799
# 3        5889993.0   4397   2.784938
# 4        7521503.0   3574   2.263673
# 5      441412723.0   2499   1.582798
# 6        5995907.0   2493   1.578997
# 7      200026573.0   2217   1.404187
# 8      238136725.0   2105   1.333249
# 9      714232249.0   1760   1.114735
# 10     433922353.0   1755   1.111569
# 11       4554150.0   1375   0.870887
# 12     723360636.0   1366   0.865187
# 13       1490291.0   1319   0.835418
# 14     304848351.0    983   0.622605
# 15     434705059.0    970   0.614371
# 16     885216069.0    899   0.569402
# 17       3573128.0    847   0.536466
# 18     147006928.0    790   0.500364
# 19     153215363.0    700   0.443361
# 20       2984524.0    638   0.404092
# 21       5644232.0    612   0.387624
# 22       6829915.0    592   0.374956
# 23     886012012.0    570   0.361022
# ...

# %% [markdown]
# **The HHI is a commonly accepted measure of market concentration. It is calculated by squaring the market share of each firm competing in a market and then summing the resulting numbers. It can range from close to 0 to 10,000. The U.S. Department of Justice uses the HHI for evaluating potential merger antitrust issues.**
#
# *Source: Investopedia*

# %%
#Calculating the HHI for the grocery industry in 2022 in the US

import numpy as np
#function used to calculate hhi 

def hhi(num):
    return np.square(num).sum()    

# hhi_df = grocery_22.groupby('PARENT NUMBER').agg({'Percent': hhi})

hhi(grocery_22['Percent'][1:]) #without the NAN PARENT NUMBER( independent stores that take up about 49% of the market)
# Out:
# 106.47089064607232

# %%
#Slicing to get the top 10 
hhi(grocery_22['Percent'][1:11])
# Out:
# 99.91353334583036

# %% [markdown]
# A market with an HHI **below 1,500** is considered a **competitive marketplace**, an HHI of 1,500 to 2,500 is moderately concentrated, and an HHI of 2,500 or greater is highly concentrated.
#
# **As a general rule, mergers that increase the HHI by more than 200 points in highly concentrated markets raise antitrust concerns, as they are assumed to enhance market power.**
#
# *Source: Investopedia*

# %% [markdown]
# ### Start date : June 29th, 2023
#
# Author : Kenthia
#
# **Goals:**
# - Observe Nationwide data, filter independent stores. Check top 50 stores by employee size and see if their name has any of the popular stores (like Krogers, Walmart etc).
#
# - Use Thefuzz and its process function. Find out string matches within all independent stores's name. Match only the top 10 parent names.
#
# - For the top 3 parent companies, individually map all their stores. Only for Illinois.
#
# - Repeat this for all counties in Illinois.

# %%
#Function that groups the Top ten parent numbers by Top ten, Independent stores and other 

import math 

def store_type(row):
    '''Based on the country T10 parent number's assigns each company to the group TOP TEN, INDEPENDENT STORE, or OTHER'''
    top_ten = [5863311.0, 450720289.0, 5889993.0, 7521503.0, 441412723.0, 5995907.0, 200026573.0, 238136725.0, 714232249.0, 433922353.0]
    
    parent_num = row['PARENT NUMBER']  
    
    if parent_num in top_ten:
        return 'TOP TEN'
    if math.isnan(parent_num):
        return 'INDEPENDENT STORE'
    
    return 'OTHER'

grocery_sic['STORE TYPE'] = grocery_sic.apply(store_type, axis=1)
grocery_sic.head()
# Out:
# /tmp/ipykernel_810333/2049661064.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grocery_sic['STORE TYPE'] = grocery_sic.apply(store_type, axis=1)
#                 COMPANY   ADDRESS LINE 1         CITY STATE  ZIPCODE    ZIP4  \
# 0                GOMART    55 POSTAL PLZ   MORGANTOWN    WV    26508  7005.0
# 1              7-ELEVEN    485 E MAIN ST    EL CENTRO    CA    92243  2619.0
# 2         EL SOL MARKET    110 W MAIN ST  WESTMORLAND    CA    92281     NaN
# 3  COOL SPRINGS GROCERY  241 WILDWOOD ST   MORGANTOWN    WV    26505  3141.0
# 4              CIRCLE K    123 E MAIN ST  WESTMORLAND    CA    92281     NaN
#
#    COUNTY CODE  AREA CODE  IDCODE LOCATION EMPLOYEE SIZE CODE  \
# ...

# %%
#Checking the count for the categories ( Top 10, Independent and Other ) 

store_type = grocery_sic.groupby("STORE TYPE").count()[["COMPANY"]].reset_index().rename(columns={"COMPANY": "COUNT"})
store_type.head()
# Out:
#           STORE TYPE  COUNT
# 0  INDEPENDENT STORE  77810
# 1              OTHER  40514
# 2            TOP TEN  39553

# %%
#Checking the sum for the total number of stores 
store_type["COUNT"].sum()
# Out:
# 157877

# %% [markdown]
# **NOTE:**

# %%
grocery_sic[grocery_sic['COMPANY'].isna()] #8 companies with no name (option would be to drop those rows)
# Out:
#        COMPANY      ADDRESS LINE 1             CITY STATE  ZIPCODE    ZIP4  \
# 24442      NaN  20207 MCKENNEY HWY      STONY CREEK    VA    23882  2229.0
# 92875      NaN     1719 KENWOOD DR       SAN ANGELO    TX    76903  8340.0
# 116742     NaN  1088 N MOONEY BLVD           TULARE    CA    93274  2417.0
# 117185     NaN    1309 E MORGAN ST     MARTINSVILLE    IN    46151  1728.0
# 142220     NaN    8111 86TH AVE NW       GIG HARBOR    WA    98332  6712.0
# 169193     NaN        3220 MAIN ST       BARNSTABLE    MA     2630  1107.0
# 174966     NaN    2613 BARRACKS RD  CHARLOTTESVILLE    VA    22901  2120.0
# 187145     NaN        610 MACON ST        MCDONOUGH    GA    30253  3532.0
#
#         COUNTY CODE  AREA CODE  IDCODE LOCATION EMPLOYEE SIZE CODE  \
# 24442          53.0        804       1                           C
# 92875         451.0        325       1                           A
# 116742        107.0        559       1                           A
# ...

# %% [markdown]
# ## LET'S FOCUS ON JUST ILLINOIS

# %%
#Subsects Illinois
il = grocery_sic.loc[grocery_sic["STATE"] == 'IL', :]
#il = il.drop(["GEOMETRY","STORE TYPE"],axis=1)

def store_type(row):
    '''Based on the country T10 parent number's assigns each company to the group TOP TEN, INDEPENDENT STORE, or OTHER'''
    top_ten_il = [441412723.0, 5863311.0, 450720289.0, 200026573.0, 5995907.0, 5889993.0, 7521503.0, 1490291.0, 723360636.0, 5644232.0]
    
    parent_num = row['PARENT NUMBER']  
    
    if parent_num in top_ten_il:
        return 'TOP TEN (IL)'
    if math.isnan(parent_num):
        return 'INDEPENDENT STORE (IL)'
    
    return 'OTHER (IL)'
il['STORE TYPE'] = il.apply(store_type, axis=1)
il.head()
# Out:
# /tmp/ipykernel_810333/1255681155.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   il['STORE TYPE'] = il.apply(store_type, axis=1)
#                        COMPANY     ADDRESS LINE 1           CITY STATE  \
# 13                      KROGER  301 E MCKINLEY RD         OTTAWA    IL
# 86                    CIRCLE K        290 MAIN ST     MARSEILLES    IL
# 199  SPRING VALLEY SUPERMARKET  117 S SPALDING ST  SPRING VALLEY    IL
# 238             FREEDOM OIL CO      402 N MAIN ST         TOLUCA    IL
# 316           SENECA FOOD MART      271 S MAIN ST         SENECA    IL
#
#      ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 13     61350  4805.0         99.0        815       2
# 86     61341     NaN         99.0        815       2
# ...

# %%
#Top 10 Parent companies in Illinois 

groc_il = il.groupby('PARENT NUMBER', dropna=False).count().reset_index()[['PARENT NUMBER','COMPANY']]
groc_il.sort_values('COMPANY', ascending=False, inplace=True)
groc_il.reset_index(drop=True,inplace=True)

groc_tp10_il = groc_il.iloc[:11]
other_groc = groc_il['COMPANY'].sum() - groc_tp10_il['COMPANY'].sum()

groc_tp10_il.loc[len(groc_tp10_il.index)] = ["Other", other_groc]
groc_tp10_il['PARENT NUMBER'] = groc_tp10_il['PARENT NUMBER'].astype(str)
groc_tp10_il.loc[:, 'Percent'] = groc_tp10_il.loc[:, 'COMPANY'] / len(il) * 100
groc_tp10_il.rename(columns={"COMPANY":"COUNT"})
# Out:
# /tmp/ipykernel_810333/1943955282.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   groc_tp10_il.loc[len(groc_tp10_il.index)] = ["Other", other_groc]
# /tmp/ipykernel_810333/1943955282.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   groc_tp10_il['PARENT NUMBER'] = groc_tp10_il['PARENT NUMBER'].astype(str)
# /tmp/ipykernel_810333/1943955282.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#FINDS IL top 5 parent companies and their employee size  
groc_il = il.groupby('PARENT NUMBER', dropna=False).agg({'EMPLOYEE SIZE (5) - LOCATION': 'sum',
                                                        'STORE TYPE': 'first'}).reset_index()
groc_il.sort_values('EMPLOYEE SIZE (5) - LOCATION', ascending=False, inplace=True)
groc_il.reset_index()
groc_il.head()

# top parent company to illinois 
#1) 441412723.0 = parent company(s)= Rutters Holding Inc, CHR Corporation
#2) 5863311.0 = parent company = Seven & I holdings
#3) 450720289.0 = parent company(s) = Alimentation Couche-Tard, Convenience Retail Asia
#4) 200026573.0 = parent company = Albrecht Discounts(aldi)
#5) 5995907.0 = parent company = Albertson
# Out:
#     PARENT NUMBER  EMPLOYEE SIZE (5) - LOCATION              STORE TYPE
# 7       5995907.0                       34245.0            TOP TEN (IL)
# 78            NaN                       17766.0  INDEPENDENT STORE (IL)
# 8       7521503.0                       11193.0            TOP TEN (IL)
# 4       5644232.0                        8702.0            TOP TEN (IL)
# 39    441412723.0                        6156.0            TOP TEN (IL)

# %% [markdown]
# ### CLEANING - FOCUSING ONLY ON THE INDEPENDENT STORES (NAN)

# %%
from thefuzz import fuzz
from thefuzz import process
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Looking at the top 50 independent stores and sorting by employee size 
country_independent = grocery_sic.loc[grocery_sic["STORE TYPE"] == "INDEPENDENT STORE", :]
country_independent_sorted = country_independent.sort_values(by=['EMPLOYEE SIZE (5) - LOCATION'], ascending=False)
country_independent50 = country_independent_sorted.iloc[:50, :]

# %%
top50 = country_independent50["COMPANY"]
top50.head()
# Out:
# 141700                 LA RAZA MARKET
# 43408             AFFILIATEDFOODS INC
# 4854      GENUARDI'S FAMILY MARKET LP
# 40083                    SSP PARTNERS
# 170019       ZABAR'S GOURMET CATERING
# Name: COMPANY, dtype: object

# %%
#uses the fuzz library to locate the string that has a similar name to the input 
#Ideally we would hope the number output is 100 or close to it to tell us its similarity
#It is being split out in the top50 slot

process.extract("Mac's convenience stores", top50, limit=10)
#citgo
# Out:
# [("HEINEN'S", 86, 109334),
#  ("MARIANA'S MARKET", 86, 146038),
#  ("O'BRIEN'S MARKET", 86, 123233),
#  ('OSI INDUSTRIES', 47, 89480),
#  ("YODER'S COUNTRY MARKET", 46, 19557),
#  ("SKOGEN'S FOODLINER INC", 46, 26142),
#  ('R F OWENS CO INC', 45, 198255),
#  ('STORE AT SANDY POND INC', 45, 93347),
#  ("WOODMAN'S FOOD MARKET INC", 43, 109228),
#  ('ALPINE MARKET', 43, 9004)]

# %% [markdown]
# ### VISUALIZATIONS - MAPPING

# %%
#Top 3 Parent Companies dataframe in Illinois without NAN included 

groc_tp3_il= il.loc[(il["PARENT NUMBER"] == 441412723.0) | (il["PARENT NUMBER"] == 5863311.0) | (il["PARENT NUMBER"] == 450720289.0) ]

groc_tp3_il.head()
# Out:
#       COMPANY         ADDRESS LINE 1        CITY STATE  ZIPCODE    ZIP4  \
# 86   CIRCLE K            290 MAIN ST  MARSEILLES    IL    61341     NaN
# 441   CASEY'S          317 S PINE ST        BUDA    IL    61314  9386.0
# 590  CIRCLE K  1727 N BLOOMINGTON ST    STREATOR    IL    61364  1315.0
# 794   CASEY'S            1327 5TH ST    LA SALLE    IL    61301  2243.0
# 818   CASEY'S          225 N MAIN ST      SENECA    IL    61360     NaN
#
#      COUNTY CODE  AREA CODE  IDCODE LOCATION EMPLOYEE SIZE CODE  \
# 86          99.0        815       2                           C
# 441         11.0        309       2                           B
# 590         99.0        815       2                           C
# 794         99.0        815       2                           C
# 818         99.0        815       2                           D
#
#     LOCATION SALES VOLUME CODE  PRIMARY SIC CODE   SIC6_DESCRIPTIONS  \
# 86                           C            541103  CONVENIENCE STORES
# ...

# %%
#Individually mapping all 3 Parent company stores 

import plotly.express as px

# Create a scattermapbox plot
fig = px.scatter_mapbox(groc_tp3_il, lat="LATITUDE", lon="LONGITUDE", hover_data=["COMPANY"], color="PARENT NUMBER", color_discrete_sequence=["blue", "green", "red"], mapbox_style="open-street-map")

fig.show()
